# %% [markdown]
# Chapter 4. PhD Thesis. Andra Sonea.
#
# Example of script for extracting bank branches using the Branch Location Open Banking API. The structure of the API is the same for all the CMA9 banks however the precise way the API is called by the developer, the branch numbering convention or its absence differ between banks. Other differences between banks:
#
# 1) the frequency of updating the data (visible in the header of the API output, field LastUpdated).
# 2) discrepancies between the API output and their website. These should be the same (i.e. a branch shoudl appear both on the website and in the API with the same location and operating schedule)
# 3) for some banks the mobile branches location (Latitude & Longitude is missing or continuously changing)
# 4) some outputs result in random formatting problems
#
# During this research I have interacted with some of the banks in regards with the errors of thier API output which made the API unusable. Some of these errors have been corrected.

# %%
import json
import pandas as pd
import numpy as np

# %%
import http.client
import json

# %% [markdown]
# #### CHANGE THE MONTH!!!

# %%
period = '2024_07'
bank = 'LBG'

# %%
input_file_json = '../../../output/'+ period + '_Branches/' + bank + '_'+ period +'.json'

output_file_json = '../../../output/'+ period + '_Branches/' + bank + '_'+ period +'.json'

output_file_csv = '../../../output/'+ period + '_Branches/'+ bank + '_'+ period + '.csv'

input_file_csv= '../../../output/'+ period + '_Branches/'+ bank + '_'+ period + '_capacity.csv'

# %%
#call the API
conn = http.client.HTTPSConnection("api.lloydsbank.com")

# %%
headers = {
    'if-modified-since': "REPLACE_THIS_VALUE",
    'if-none-match': "REPLACE_THIS_VALUE",
    'accept': "application/prs.openbanking.opendata.v2.2+json"
    }

conn.request("GET", "/open-banking/v2.2/branches", headers=headers)
conn

# %%
res = conn.getresponse()
res

# %%
data_raw = res.read()
data_raw
# Out:
# b'{\n    "meta": {\n        "LastUpdated": "2024-06-24T08:30:14.480Z",\n        "TotalResults": 547,\n        "Agreement": "Use of the APIs and any related data will be subject to the terms of the Open Licence and subject to terms and conditions",\n        "License": "https://www.openbanking.org.uk/open-licence",\n        "TermsOfUse": "https://www.openbanking.org.uk/terms-conditions"\n    },\n    "data": [\n        {\n            "Brand": [\n                {\n                    "BrandName": "Lloyds Bank",\n                    "Branch": [\n                        {\n                            "Identification": "30109100",\n                            "SequenceNumber": "00",\n                            "Name": "Bishopsworth",\n                            "Type": "Physical",\n                            "CustomerSegment": [\n                                "Personal",\n                                "Business"\n                            ],\n                            "Availability": {\n                                "StandardAvailability": {\n                                    "Day": [\n                                        {\n                                            "Name": "Monday",\n                                            "OpeningHours": [\n                                                {\n                                                    "OpeningTime": "09:30",\n                                                    "ClosingTime": "16:30"\n                                                }\n                                            ]\n                                        },\n                                        {\n                                            "Name": "Tuesday",\n                                            "OpeningHours": [\n                                                {\n                                                    "OpeningTime": "09:30",\n                                                    "ClosingTime": "16:30"\n                                                }\n                                            ]\n                                        },\n                                        {\n                                            "Name": "Wednesday",\n                                            "OpeningHours": [\n                                                {\n                                                    "OpeningTime": "09:30",\n                                                    "ClosingTime": "16:30"\n                                                }\n                                            ]\n                                        },\n                                        {\n                                            "Name": "Thursday",\n                                            "OpeningHours": [\n                                                {\n                                                    "OpeningTime": "09:30",\n                                                    "ClosingTime": "16:30"\n                                                }\n                                            ]\n                                        },\n                                        {\n                                            "Name": "Friday",\n                                            "OpeningHours": [\n                                                {\n                                                    "OpeningTime": "09:30",\n                                                    "ClosingTime": "16:30"\n                                                }\n                                            ]\n                                        }\n                                    ]\n                                }\n                            },\n                            "ContactInfo": [\n                                {\n                                    "ContactType": "Phone",\n                                    "ContactContent": "+44-3 ...

# %%
data = json.loads(data_raw.decode('utf-8'), encoding='utf-8')
data
# Out:
# {'meta': {'LastUpdated': '2024-06-24T08:30:14.480Z',
#   'TotalResults': 547,
#   'Agreement': 'Use of the APIs and any related data will be subject to the terms of the Open Licence and subject to terms and conditions',
#   'License': 'https://www.openbanking.org.uk/open-licence',
#   'TermsOfUse': 'https://www.openbanking.org.uk/terms-conditions'},
#  'data': [{'Brand': [{'BrandName': 'Lloyds Bank',
#      'Branch': [{'Identification': '30109100',
#        'SequenceNumber': '00',
#        'Name': 'Bishopsworth',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '16:30'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '16:30'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '16:30'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '16:30'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:30',
#              'ClosingTime': '16:30'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['16 Highridge Road'],
#         'TownName': 'Bishopsworth',
#         'CountrySubDivision': ['Bristol'],
#         'Country': 'GB',
#         'PostCode': 'BS13 8HA',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.4126387',
#           'Longitude': '-2.621303'}}}},
#       {'Identification': '30117500',
#        'SequenceNumber': '00',
#        'Name': 'Coxs & Kings',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '10:00', 'ClosingTime': '16:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '10:00', 'ClosingTime': '16:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '10:00', 'ClosingTime': '16:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '10:00', 'ClosingTime': '16:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '10:00',
#              'ClosingTime': '16:00'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['Villiers House 48-49 Strand'],
#         'CountrySubDivision': ['London'],
#         'Country': 'GB',
#         'PostCode': 'WC2N 5LL',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.5090849',
#           'Longitude': '-0.1240127'}}}},
#       {'Identification': '77855000',
#        'SequenceNumber': '00',
#        'Name': 'Castle Bromwich',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00',
#              'ClosingTime': '15:30'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['299 Chester Road'],
#         'TownName': 'Castle Bromwich',
#         'CountrySubDivision': ['Birmingham'],
#         'Country': 'GB',
#         'PostCode': 'B36 0JG',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '52.501616',
#           'Longitude': '-1.7625594'}}}},
#       {'Identification': '30125100',
#        'SequenceNumber': '00',
#        'Name': 'Cowley',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '09:00',
#              'ClosingTime': '13:00'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['1 Pound Way Cowley'],
#         'TownName': 'Oxford',
#         'CountrySubDivision': ['Oxfordshire'],
#         'Country': 'GB',
#         'PostCode': 'OX4 3XS',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.732031',
#           'Longitude': '-1.2182259'}}}},
#       {'Identification': '30125700',
#        'SequenceNumber': '00',
#        'Name': 'Cramlington',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '09:00',
#              'ClosingTime': '13:00'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['Dudley Court East Square'],
#         'TownName': 'Cramlington',
#         'CountrySubDivision': ['Northumberland'],
#         'Country': 'GB',
#         'PostCode': 'NE23 6QR',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '55.0853875',
#           'Longitude': '-1.5880698'}}}},
#       {'Identification': '30128600',
#        'SequenceNumber': '00',
#        'Name': 'Driffield',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00',
#              'ClosingTime': '15:00'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['15 Market Place'],
#         'TownName': 'Driffield',
#         'CountrySubDivision': ['East Yorkshire'],
#         'Country': 'GB',
#         'PostCode': 'YO25 6AH',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '54.005187',
#           'Longitude': '-0.4396941'}}}},
#       {'Identification': '77010700',
#        'SequenceNumber': '00',
#        'Name': 'Glossop',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00',
#              'ClosingTime': '15:00'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['2 High Street East'],
#         'TownName': 'Glossop',
#         'CountrySubDivision': ['Derbyshire'],
#         'Country': 'GB',
#         'PostCode': 'SK13 8DA',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '53.4431716',
#           'Longitude': '-1.9487313'}}}},
#       {'Identification': '30135600',
#        'SequenceNumber': '00',
#        'Name': 'Hailsham',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00',
#              'ClosingTime': '15:00'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['Market Street'],
#         'TownName': 'Hailsham',
#         'CountrySubDivision': ['East Sussex'],
#         'Country': 'GB',
#         'PostCode': 'BN27 2AE',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '50.8620795',
#           'Longitude': '0.2604583'}}}},
#       {'Identification': '30139500',
#        'SequenceNumber': '00',
#        'Name': 'Southampton Hedge End',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00',
#              'ClosingTime': '15:00'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ["St John's Centre Hedge End"],
#         'TownName': 'Southampton',
#         'CountrySubDivision': ['Hampshire'],
#         'Country': 'GB',
#         'PostCode': 'SO30 4QU',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '50.9128555',
#           'Longitude': '-1.304455'}}}},
#       {'Identification': '77131200',
#        'SequenceNumber': '00',
#        'Name': 'Hornchurch',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00',
#              'ClosingTime': '15:30'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['21-25 Station Lane'],
#         'TownName': 'Hornchurch',
#         'CountrySubDivision': ['Essex'],
#         'Country': 'GB',
#         'PostCode': 'RM12 6JL',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.5609331',
#           'Longitude': '0.2211282'}}}},
#       {'Identification': '30144800',
#        'SequenceNumber': '00',
#        'Name': 'Kingsbury',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00',
#              'ClosingTime': '15:00'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['445 Kingsbury Road'],
#         'TownName': 'Kingsbury',
#         'CountrySubDivision': ['London'],
#         'Country': 'GB',
#         'PostCode': 'NW9 9DX',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.5858',
#           'Longitude': '-0.27553'}}}},
#       {'Identification': '30145100',
#        'SequenceNumber': '00',
#        'Name': 'Kingswinford',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00',
#              'ClosingTime': '15:30'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['70 High Street'],
#         'TownName': 'Kingswinford',
#         'CountrySubDivision': ['West Midlands'],
#         'Country': 'GB',
#         'PostCode': 'DY6 8AE',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '52.4972803',
#           'Longitude': '-2.1675744'}}}},
#       {'Identification': '30147600',
#        'SequenceNumber': '00',
#        'Name': 'Leyland',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00',
#              'ClosingTime': '15:00'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['12 Hough Lane Leyland'],
#         'TownName': 'Preston',
#         'CountrySubDivision': ['Lancashire'],
#         'Country': 'GB',
#         'PostCode': 'PR25 2SD',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '53.6946727',
#           'Longitude': '-2.6949347'}}}},
#       {'Identification': '30149600',
#        'SequenceNumber': '00',
#        'Name': 'Llangefni',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '14:30'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '14:30'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00',
#              'ClosingTime': '14:30'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['23 High Street'],
#         'TownName': 'Llangefni',
#         'CountrySubDivision': ['Anglesey'],
#         'Country': 'GB',
#         'PostCode': 'LL77 7NB',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '53.256014',
#           'Longitude': '-4.3126023'}}}},
#       {'Identification': '30153900',
#        'SequenceNumber': '00',
#        'Name': 'Market Drayton',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00',
#              'ClosingTime': '15:00'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['55 Cheshire Street'],
#         'TownName': 'Market Drayton',
#         'CountrySubDivision': ['Shropshire'],
#         'Country': 'GB',
#         'PostCode': 'TF9 1PN',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '52.9053507',
#           'Longitude': '-2.4859716'}}}},
#       {'Identification': '30155300',
#        'SequenceNumber': '00',
#        'Name': 'Milton Keynes',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '09:00',
#              'ClosingTime': '15:00'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['Lloyds Court 28 Secklow Gate West'],
#         'TownName': 'Milton Keynes',
#         'CountrySubDivision': ['Buckinghamshire'],
#         'Country': 'GB',
#         'PostCode': 'MK9 3EH',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '52.0448836',
#           'Longitude': '-0.7572731'}}}},
#       {'Identification': '30162000',
#        'SequenceNumber': '00',
#        'Name': 'Pembroke Dock',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '16:30'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '16:30'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '16:30'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '16:30'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:30',
#              'ClosingTime': '16:30'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['35 Dimond Street'],
#         'TownName': 'Pembroke Dock',
#         'CountrySubDivision': ['Pembrokeshire'],
#         'Country': 'GB',
#         'PostCode': 'SA72 6BX',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.69378',
#           'Longitude': '-4.9402864'}}}},
#       {'Identification': '77092300',
#        'SequenceNumber': '00',
#        'Name': 'Plymstock',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00',
#              'ClosingTime': '15:00'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['3-5 The Broadway Plymstock'],
#         'TownName': 'Plymouth',
#         'CountrySubDivision': ['Devon'],
#         'Country': 'GB',
#         'PostCode': 'PL9 7AD',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '50.3597685',
#           'Longitude': '-4.0923992'}}}},
#       {'Identification': '30164000',
#        'SequenceNumber': '00',
#        'Name': 'Pontardawe',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '14:30'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '14:30'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '14:30'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00',
#              'ClosingTime': '14:30'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['66 Herbert Street'],
#         'TownName': 'Pontardawe',
#         'CountrySubDivision': ['Neath Port Talbot'],
#         'Country': 'GB',
#         'PostCode': 'SA8 4ED',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.7195682',
#           'Longitude': '-3.8497262'}}}},
#       {'Identification': '30164800',
#        'SequenceNumber': '00',
#        'Name': 'Pontyclun',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '16:30'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '16:30'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '16:30'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '16:30'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:30',
#              'ClosingTime': '16:30'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['39 Cowbridge Road'],
#         'TownName': 'Pontyclun',
#         'CountrySubDivision': ['Rhondda Cynon Taff'],
#         'Country': 'GB',
#         'PostCode': 'CF72 9EB',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.522186',
#           'Longitude': '-3.3918162'}}}},
#       {'Identification': '30165600',
#        'SequenceNumber': '00',
#        'Name': 'Portishead',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00',
#              'ClosingTime': '15:30'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['High Street'],
#         'TownName': 'Portishead',
#         'CountrySubDivision': ['Bristol'],
#         'Country': 'GB',
#         'PostCode': 'BS20 6BJ',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.484178',
#           'Longitude': '-2.769425'}}}},
#       {'Identification': '30166800',
#        'SequenceNumber': '00',
#        'Name': 'Presteigne',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00',
#              'ClosingTime': '15:00'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['52 Hereford Street'],
#         'TownName': 'Presteigne',
#         'CountrySubDivision': ['Powys'],
#         'Country': 'GB',
#         'PostCode': 'LD8 2AU',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '52.2726732',
#           'Longitude': '-3.0058827'}}}},
#       {'Identification': '30177200',
#        'SequenceNumber': '00',
#        'Name': 'Saltash',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00',
#              'ClosingTime': '15:30'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['67 Fore Street'],
#         'TownName': 'Saltash',
#         'CountrySubDivision': ['Cornwall'],
#         'Country': 'GB',
#         'PostCode': 'PL12 6AJ',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '50.4085289',
#           'Longitude': '-4.2116219'}}}},
#       {'Identification': '30180600',
#        'SequenceNumber': '00',
#        'Name': 'Sittingbourne',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '09:00',
#              'ClosingTime': '13:00'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['125 High Street'],
#         'TownName': 'Sittingbourne',
#         'CountrySubDivision': ['Kent'],
#         'Country': 'GB',
#         'PostCode': 'ME10 4BD',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.3402225',
#           'Longitude': '0.7336663'}}}},
#       {'Identification': '30183000',
#        'SequenceNumber': '00',
#        'Name': 'Haywards Heath',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00',
#              'ClosingTime': '15:30'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['99/101 South Road'],
#         'TownName': 'Haywards Heath',
#         'CountrySubDivision': ['West Sussex'],
#         'Country': 'GB',
#         'PostCode': 'RH16 4ND',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '50.9972882',
#           'Longitude': '-0.1033311'}}}},
#       {'Identification': '30185500',
#        'SequenceNumber': '00',
#        'Name': 'Telford',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '09:00',
#              'ClosingTime': '15:00'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['113 The Border Telford Town Centre'],
#         'TownName': 'Telford',
#         'CountrySubDivision': ['Shropshire'],
#         'Country': 'GB',
#         'PostCode': 'TF3 4AE',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '52.6767622',
#           'Longitude': '-2.4461047'}}}},
#       {'Identification': '30185600',
#        'SequenceNumber': '00',
#        'Name': 'Wolverhampton Tettenhall',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00',
#              'ClosingTime': '15:30'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['28a High Street Tettenhall'],
#         'TownName': 'Wolverhampton',
#         'CountrySubDivision': ['West Midlands'],
#         'Country': 'GB',
#         'PostCode': 'WV6 8QT',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '52.5975385',
#           'Longitude': '-2.1683416'}}}},
#       {'Identification': '30186200',
#        'SequenceNumber': '00',
#        'Name': 'Thornbury',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00',
#              'ClosingTime': '15:00'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['5 High Street'],
#         'TownName': 'Thornbury',
#         'CountrySubDivision': ['Gloucestershire'],
#         'Country': 'GB',
#         'PostCode': 'BS35 2AE',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.6088951',
#           'Longitude': '-2.5257985'}}}},
#       {'Identification': '30188200',
#        'SequenceNumber': '00',
#        'Name': 'Tottenham Court Road',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '10:00', 'ClosingTime': '16:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '10:00', 'ClosingTime': '16:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '10:00', 'ClosingTime': '16:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '10:00', 'ClosingTime': '16:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '10:00',
#              'ClosingTime': '16:00'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['88 Tottenham Court Road'],
#         'CountrySubDivision': ['London'],
#         'Country': 'GB',
#         'PostCode': 'W1T 4TH',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.521843',
#           'Longitude': '-0.135909'}}}},
#       {'Identification': '30188800',
#        'SequenceNumber': '00',
#        'Name': 'Clevedon',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '09:00',
#              'ClosingTime': '13:00'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['16 The Triangle'],
#         'TownName': 'Clevedon',
#         'CountrySubDivision': ['Bristol'],
#         'Country': 'GB',
#         'PostCode': 'BS21 6NG',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.4360915',
#           'Longitude': '-2.8519057'}}}},
#       {'Identification': '77717200',
#        'SequenceNumber': '00',
#        'Name': 'Wetherby',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '14:30'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '14:30'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '14:30'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '14:30'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00',
#              'ClosingTime': '14:30'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['55 Market Place'],
#         'TownName': 'Wetherby',
#         'CountrySubDivision': ['West Yorkshire'],
#         'Country': 'GB',
#         'PostCode': 'LS22 6LN',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '53.9285231',
#           'Longitude': '-1.3862046'}}}},
#       {'Identification': '30415700',
#        'SequenceNumber': '00',
#        'Name': 'Stratford Westfield',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '10:00', 'ClosingTime': '18:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '10:00', 'ClosingTime': '18:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '10:00', 'ClosingTime': '18:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '10:00', 'ClosingTime': '18:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '10:00', 'ClosingTime': '18:00'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '10:00',
#              'ClosingTime': '16:00'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['52-53 The Arcade Westfield Stratford City'],
#         'TownName': 'Montfichet Road',
#         'CountrySubDivision': ['London'],
#         'Country': 'GB',
#         'PostCode': 'E20 1EH',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.54359',
#           'Longitude': '-0.00664'}}}},
#       {'Identification': '30623200',
#        'SequenceNumber': '00',
#        'Name': 'Patchway',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '16:30'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '16:30'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '16:30'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '16:30'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:30',
#              'ClosingTime': '16:30'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['61 Gloucester Road'],
#         'TownName': 'Patchway',
#         'CountrySubDivision': ['Bristol'],
#         'Country': 'GB',
#         'PostCode': 'BS34 5JH',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.5280857',
#           'Longitude': '-2.5710498'}}}},
#       {'Identification': '30624600',
#        'SequenceNumber': '00',
#        'Name': 'Hounslow',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '09:00',
#              'ClosingTime': '15:00'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['Treaty Centre'],
#         'TownName': 'Hounslow',
#         'CountrySubDivision': ['Middlesex'],
#         'Country': 'GB',
#         'PostCode': 'TW3 1ES',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.4680721',
#           'Longitude': '-0.3639239'}}}},
#       {'Identification': '30625500',
#        'SequenceNumber': '00',
#        'Name': 'Rotherham',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '09:00',
#              'ClosingTime': '13:00'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['9 Wellgate'],
#         'TownName': 'Rotherham',
#         'CountrySubDivision': ['South Yorkshire'],
#         'Country': 'GB',
#         'PostCode': 'S60 2LU',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '53.4302495',
#           'Longitude': '-1.3543196'}}}},
#       {'Identification': '30629600',
#        'SequenceNumber': '00',
#        'Name': 'Cabot Circus',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '17:30'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '17:30'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '17:30'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '17:30'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '17:30'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '09:00',
#              'ClosingTime': '15:00'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['44-45 George White Street'],
#         'TownName': 'Cabot Circus',
#         'CountrySubDivision': ['Bristol'],
#         'Country': 'GB',
#         'PostCode': 'BS1 3BA',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.4583927',
#           'Longitude': '-2.5858613'}}}},
#       {'Identification': '30634700',
#        'SequenceNumber': '00',
#        'Name': 'Boston',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '16:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '16:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '16:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '16:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '16:00'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '09:00',
#              'ClosingTime': '13:00'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['51 Market Place'],
#         'TownName': 'Boston',
#         'CountrySubDivision': ['Lincolnshire'],
#         'Country': 'GB',
#         'PostCode': 'PE21 6NQ',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '52.9782062',
#           'Longitude': '-0.0246888'}}}},
#       {'Identification': '30635400',
#        'SequenceNumber': '00',
#        'Name': 'Bracknell',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '09:00',
#              'ClosingTime': '13:00'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['10 High Street'],
#         'TownName': 'Bracknell',
#         'CountrySubDivision': ['Berkshire'],
#         'Country': 'GB',
#         'PostCode': 'RG12 1BT',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.4164819',
#           'Longitude': '-0.7476843'}}}},
#       {'Identification': '30635500',
#        'SequenceNumber': '00',
#        'Name': 'Bradford',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '09:00',
#              'ClosingTime': '15:00'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['45 Hustlergate'],
#         'TownName': 'Bradford',
#         'CountrySubDivision': ['West Yorkshire'],
#         'Country': 'GB',
#         'PostCode': 'BD1 1NT',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '53.7945328',
#           'Longitude': '-1.7522146'}}}},
#       {'Identification': '30635700',
#        'SequenceNumber': '00',
#        'Name': 'Braintree',
#        'Type': 'Physical',
# ...
#              'ClosingTime': '15:00'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['106 Kilburn High Road'],
#         'TownName': 'Kilburn',
#         'CountrySubDivision': ['London'],
#         'Country': 'GB',
#         'PostCode': 'NW6 4HY',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.5391941',
#           'Longitude': '-0.1945425'}}}},
#       {'Identification': '77912200',
#        'SequenceNumber': '00',
#        'Name': 'Stratford Broadway',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '09:00',
#              'ClosingTime': '15:00'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['60 The Broadway'],
#         'TownName': 'Stratford',
#         'CountrySubDivision': ['London'],
#         'Country': 'GB',
#         'PostCode': 'E15 1NG',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.541441',
#           'Longitude': '0.0018097'}}}},
#       {'Identification': '30990200',
#        'SequenceNumber': '00',
#        'Name': 'Fulham',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00',
#              'ClosingTime': '15:30'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['417 North End Road'],
#         'TownName': 'Fulham',
#         'CountrySubDivision': ['London'],
#         'Country': 'GB',
#         'PostCode': 'SW6 1NS',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.4824523',
#           'Longitude': '-0.1999726'}}}},
#       {'Identification': '77912900',
#        'SequenceNumber': '00',
#        'Name': 'Lewisham',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '09:00',
#              'ClosingTime': '15:00'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['120 Lewisham High Street'],
#         'TownName': 'Lewisham',
#         'CountrySubDivision': ['London'],
#         'Country': 'GB',
#         'PostCode': 'SE13 6JG',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.4619757',
#           'Longitude': '-0.0127759'}}}},
#       {'Identification': '30675000',
#        'SequenceNumber': '00',
#        'Name': 'Streatham',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '09:00',
#              'ClosingTime': '15:00'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['186 Streatham High Road'],
#         'TownName': 'Streatham',
#         'CountrySubDivision': ['London'],
#         'Country': 'GB',
#         'PostCode': 'SW16 1BE',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.4320453',
#           'Longitude': '-0.1296107'}}}},
#       {'Identification': '77913600',
#        'SequenceNumber': '00',
#        'Name': 'North Finchley',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '09:00',
#              'ClosingTime': '15:00'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['841 High Road'],
#         'TownName': 'North Finchley',
#         'CountrySubDivision': ['London'],
#         'Country': 'GB',
#         'PostCode': 'N12 8PX',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.61742',
#           'Longitude': '-0.1771'}}}},
#       {'Identification': '30845100',
#        'SequenceNumber': '00',
#        'Name': 'Bromley',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '09:00',
#              'ClosingTime': '15:00'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['6-8 Market Square'],
#         'TownName': 'Bromley',
#         'CountrySubDivision': ['Kent'],
#         'Country': 'GB',
#         'PostCode': 'BR1 1NA',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.4058152',
#           'Longitude': '0.0149436'}}}},
#       {'Identification': '77914500',
#        'SequenceNumber': '00',
#        'Name': 'Southall',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '09:00',
#              'ClosingTime': '15:00'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['25 The Broadway'],
#         'TownName': 'Southall',
#         'CountrySubDivision': ['Middlesex'],
#         'Country': 'GB',
#         'PostCode': 'UB1 1JT',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.51129',
#           'Longitude': '-0.37689'}}}},
#       {'Identification': '77914600',
#        'SequenceNumber': '00',
#        'Name': 'Hayes',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00',
#              'ClosingTime': '17:00'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['1-5 East Avenue'],
#         'TownName': 'Hayes',
#         'CountrySubDivision': ['Middlesex'],
#         'Country': 'GB',
#         'PostCode': 'UB3 2HW',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.5073215',
#           'Longitude': '-0.4184215'}}}},
#       {'Identification': '77915600',
#        'SequenceNumber': '00',
#        'Name': 'Walthamstow',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '09:00',
#              'ClosingTime': '15:00'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['180 - 182 High Street'],
#         'TownName': 'Walthamstow',
#         'CountrySubDivision': ['London'],
#         'Country': 'GB',
#         'PostCode': 'E17 7JH',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.584015',
#           'Longitude': '-0.0235759'}}}},
#       {'Identification': '77916800',
#        'SequenceNumber': '00',
#        'Name': 'Edmonton Green',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '09:00',
#              'ClosingTime': '13:00'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['37 South Mall Edmonton Green Shopping Centre'],
#         'TownName': 'Edmonton Green',
#         'CountrySubDivision': ['London'],
#         'Country': 'GB',
#         'PostCode': 'N9 0TZ',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.624249',
#           'Longitude': '-0.058165'}}}},
#       {'Identification': '77950400',
#        'SequenceNumber': '00',
#        'Name': 'Southampton Above Bar St',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '09:00',
#              'ClosingTime': '15:00'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['92-94 Above Bar Street'],
#         'TownName': 'Southampton',
#         'CountrySubDivision': ['Hampshire'],
#         'Country': 'GB',
#         'PostCode': 'SO14 7DT',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '50.9054982',
#           'Longitude': '-1.4040536'}}}},
#       {'Identification': '77952600',
#        'SequenceNumber': '00',
#        'Name': 'Hemel Hempstead',
#        'Type': 'Physical',
#        'CustomerSegment': ['Personal', 'Business'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '15:30'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '09:00',
#              'ClosingTime': '13:00'}]}]}},
#        'ContactInfo': [{'ContactType': 'Phone',
#          'ContactContent': '+44-3456021997'}],
#        'PostalAddress': {'AddressLine': ['198-200 The Marlowes'],
#         'TownName': 'Hemel Hempstead',
#         'CountrySubDivision': ['Hertfordshire'],
#         'Country': 'GB',
#         'PostCode': 'HP1 1BH',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.7501605',
#           'Longitude': '-0.4727745'}}}}]}]}]}

# %%
with open(output_file_json, 'w') as f:
    json.dump(data, f)

# %%
with open(input_file_json, "r") as read_file:
    data = json.load(read_file)

# %%
f = open(output_file_csv, "w")

f.write('Brand,ID,Type,Branch Name,Town,Postcode,Lat,Long,MonOp,MonCls,TueOp,TueCls,WedOp,WedCls,ThuOp,ThuCls,FriOp,FriCls,SatOp,SatCls,SunOp,SunCls\n')

for brand in data['data'][0]['Brand']:
    for branch in brand['Branch']:
        ID = branch['Identification']
        Btype =  branch ['Type']
        BName = branch['Name']
        town = branch ['PostalAddress'].get('TownName', 'None')
        postcode = branch['PostalAddress']['PostCode']
        try:
            latitude = float(branch ['PostalAddress']['GeoLocation']['GeographicCoordinates']['Latitude'])
            longitude = float(branch['PostalAddress']['GeoLocation']['GeographicCoordinates']['Longitude'])
        except KeyError:
            latitude = 0
            longitude = 0
            
        days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
        opening = {day: {'Open':'', 'Close': ''} for day in days}
        try:
            availability = branch['Availability']['StandardAvailability']['Day']
            for day in availability:
                opening[day['Name']]['Open'] = day['OpeningHours'][0]['OpeningTime']
                opening[day['Name']]['Close'] = day['OpeningHours'][0]['ClosingTime']
        except KeyError:
            pass
        f.write('{0},{1},{2},{3},{4},{5},{6:6f},{7:6f}'.format(brand['BrandName'], ID, Btype, BName, town, postcode, latitude, longitude))
        for day in days:
            f.write(',{0},{1}'.format(opening[day]['Open'],opening[day]['Close']))
        f.write('\n')
f.close()

# %% [markdown]
# The branches data is not always correctly formatted. For one or two records the Postcode will appear in the latutide field. As there are not rules, better to correct the formatting manually. Afterwards, re-start the script from here.
#
# - for 2023/01 two branches were wrongly formatted and I copied their Longitude from the previous period

# %%
branches = pd.read_csv(output_file_csv)

# %%
branches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 547 entries, 0 to 546
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Brand        547 non-null    object
#  1   ID           547 non-null    int64
#  2   Type         547 non-null    object
#  3   Branch Name  547 non-null    object
#  4   Town         547 non-null    object
#  5   Postcode     547 non-null    object
#  6   Lat          547 non-null    float64
#  7   Long         547 non-null    float64
#  8   MonOp        545 non-null    object
#  9   MonCls       545 non-null    object
#  10  TueOp        535 non-null    object
#  11  TueCls       535 non-null    object
#  12  WedOp        536 non-null    object
#  13  WedCls       536 non-null    object
#  14  ThuOp        542 non-null    object
#  15  ThuCls       542 non-null    object
#  16  FriOp        534 non-null    object
#  17  FriCls       534 non-null    object
#  18  SatOp        299 non-null    object
#  19  SatCls       299 non-null    object
#  20  SunOp        1 non-null      object
#  21  SunCls       1 non-null      object
# dtypes: float64(2), int64(1), object(19)
# memory usage: 94.1+ KB

# %%
branches['Lat'] = branches['Lat'].astype(float)

# %%
#calculate total open time (in minutes), on a Monday
branches['MonDuration']=(pd.to_datetime(branches['MonCls']) - pd.to_datetime(branches['MonOp']))/np.timedelta64(1,'m')

# %%
#calculate total open time (in minutes), on a Tuesday
branches['TueDuration']=(pd.to_datetime(branches['TueCls']) - pd.to_datetime(branches['TueOp']))/np.timedelta64(1,'m')

# %%
#calculate total open time (in minutes), on a Wednesday
branches['WedDuration']=(pd.to_datetime(branches['WedCls']) - pd.to_datetime(branches['WedOp']))/np.timedelta64(1,'m')

# %%
#calculate total open time (in minutes), on a Thursday
branches['ThuDuration']=(pd.to_datetime(branches['ThuCls']) - pd.to_datetime(branches['ThuOp']))/np.timedelta64(1,'m')

# %%
#calculate total open time (in minutes), on a Friday
branches['FriDuration']=(pd.to_datetime(branches['FriCls']) - pd.to_datetime(branches['FriOp']))/np.timedelta64(1,'m')

# %%
#calculate total open time (in minutes), on a Saturday
branches['SatDuration']=(pd.to_datetime(branches['SatCls']) - pd.to_datetime(branches['SatOp']))/np.timedelta64(1,'m')

# %%
#calculate total open time (in minutes), on a Sunday
branches['SunDuration']=(pd.to_datetime(branches['SunCls']) - pd.to_datetime(branches['SunOp']))/np.timedelta64(1,'m')

# %%
branches['MonDuration'] = branches['MonDuration'].fillna(0)
branches['TueDuration'] = branches['TueDuration'].fillna(0)
branches['WedDuration'] = branches['WedDuration'].fillna(0)
branches['ThuDuration'] = branches['ThuDuration'].fillna(0)
branches['FriDuration'] = branches['FriDuration'].fillna(0)
branches['SatDuration'] = branches['SatDuration'].fillna(0)
branches['SunDuration'] = branches['SunDuration'].fillna(0)

# %%
branches['TotalWkOp']= branches['MonDuration']+branches['TueDuration']+ \
                        branches['WedDuration']+branches['ThuDuration']+ \
                        branches['FriDuration']+branches['SatDuration']+branches['SunDuration']

# %% [markdown]
# Calculation of Capacity where the 2790min/week was the assumed "normal branch" in 2019. This threshold was abandoned later on in the thesis because the typology and the schedules of bank branches started varying much more. There is no "normal branch" anymore.

# %%
# Capacity
branches['Capacity']= branches['TotalWkOp']/2790

# %%
# Save points file as csv
branches.to_csv(input_file_csv)
