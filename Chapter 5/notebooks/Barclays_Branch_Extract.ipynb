# %% [markdown]
# ## Libraries

# %%
import requests
import json

# %%
#data manipulation + import
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
import json
import http.client

# %%
#dealing with time
import datetime
from datetime import datetime

# %% [markdown]
# ## Import branches through open banking API

# %% [markdown]
# # CHANGE THE PERIOD

# %%
period = '2024_05'
bank = 'Barclays'

# %%
#definition of output file path

input_file_json = '../../../output/'+ period + '_Branches/' + bank + '_'+ period +'.json'

output_file_json = '../../../output/'+ period + '_Branches/' + bank + '_'+ period +'.json'

input_file_csv = '../../../output/'+ period + '_Branches/'+ bank + '_'+ period + '.csv'

output_file_csv = '../../../output/'+ period + '_Branches/'+ bank + '_'+ period + '_capacity.csv'

# %% [markdown]
# Calling the barclays API

# %%
url = "https://atlas.api.barclays:443/open-banking/v2.2/branches"
headers = { "cache-control" : "no cache"}

#https://atlas.api.barclays:443/open-banking/v2.2

# %%
#params = {"positions":[0,6,7,29]}

# Make a get request with the parameters.
response = requests.get(url, headers=headers)

# Print the content of the response
#print(response.content)

# %%
data = response.json()

# %% [markdown]
# The resonse has two parts:
#
# metadata (data['metadata']
# actual data (data['data']
# Here we display the content of the metadata. This includes information about the last time the data was updated on the backend, the number of results, etc:
#
# data['meta']
# data['meta']

# %%
data['meta']
# Out:
# {'LastUpdated': '2024-05-01T14:30:06+0100',
#  'TotalResults': 726,
#  'Agreement': 'Use of the APIs and any related data will be subject to the terms of the Open Licence and subject to terms and conditions',
#  'License': 'https://www.openbanking.org.uk/open-licence',
#  'TermsOfUse': 'https://www.openbanking.org.uk/terms'}

# %%
with open(output_file_json, 'w') as f:
    json.dump(data, f)

# %%
with open(input_file_json, "r") as read_file:
    data = json.load(read_file)

# %%
data
# Out:
# {'meta': {'LastUpdated': '2024-05-01T14:30:06+0100',
#   'TotalResults': 726,
#   'Agreement': 'Use of the APIs and any related data will be subject to the terms of the Open Licence and subject to terms and conditions',
#   'License': 'https://www.openbanking.org.uk/open-licence',
#   'TermsOfUse': 'https://www.openbanking.org.uk/terms'},
#  'data': [{'Brand': [{'BrandName': 'Barclays UK',
#      'Branch': [{'Identification': 'UK-B-20031804',
#        'SequenceNumber': '0',
#        'Name': 'Barclays Bank',
#        'Type': 'Physical',
#        'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/flex-images/Local Generic Image.jpg',
#        'CustomerSegment': ['Private',
#         'SME',
#         'Premier',
#         'Select',
#         'Wealth',
#         'Corporate',
#         'Business',
#         'Personal'],
#        'Accessibility': ['WheelchairAccess', 'InductionLoop'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '16:30'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '16:30'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '16:30'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Sunday',
#            'OpeningHours': [{'OpeningTime': '00:00',
#              'ClosingTime': '00:00'}]}]}},
#        'ContactInfo': [{'ContactContent': '+44-3457345345',
#          'ContactDescription': 'Phone'}],
#        'PostalAddress': {'AddressLine': ['Leighton Buzzard Library Theatre'],
#         'BuildingNumber': 'Barclays Bank',
#         'StreetName': 'Local - Leighton Buzzard',
#         'TownName': 'Lake Street, Leighton Buzzard',
#         'CountrySubDivision': ['Bedfordshire'],
#         'Country': 'UK',
#         'PostCode': 'LU7 1RX',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.91501320',
#           'Longitude': '-0.65907430'}}}},
#       {'Identification': 'UK-B-20748104',
#        'SequenceNumber': '0',
#        'Name': 'Barclays Bank',
#        'Type': 'Physical',
#        'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/flex-images/local-a-h/Biggleswade.jpg',
#        'CustomerSegment': ['Private',
#         'SME',
#         'Premier',
#         'Select',
#         'Wealth',
#         'Corporate',
#         'Business',
#         'Personal'],
#        'Accessibility': ['WheelchairAccess', 'InductionLoop'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '16:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '16:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '16:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Sunday',
#            'OpeningHours': [{'OpeningTime': '00:00',
#              'ClosingTime': '00:00'}]}]}},
#        'ContactInfo': [{'ContactContent': '+44-3457345345',
#          'ContactDescription': 'Phone'}],
#        'PostalAddress': {'AddressLine': ['The Library, Chestnut Avenue'],
#         'BuildingNumber': 'Barclays Bank',
#         'StreetName': 'Local - Biggleswade',
#         'TownName': 'Biggleswade',
#         'CountrySubDivision': ['Bedfordshire'],
#         'Country': 'UK',
#         'PostCode': 'SG18 0LL',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '52.08779860',
#           'Longitude': '-0.25938720'}}}},
#       {'Identification': '66000226',
#        'SequenceNumber': '0',
#        'Name': 'Barclays Bank',
#        'Type': 'Physical',
#        'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/flex-images/Local Generic Image.jpg',
#        'CustomerSegment': ['Private',
#         'SME',
#         'Premier',
#         'Select',
#         'Wealth',
#         'Corporate',
#         'Business',
#         'Personal'],
#        'Accessibility': ['InductionLoop', 'WheelchairAccess'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '14:30'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '14:30'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '14:30'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Sunday',
#            'OpeningHours': [{'OpeningTime': '00:00',
#              'ClosingTime': '00:00'}]}]}},
#        'ContactInfo': [{'ContactContent': '+44-3457345345',
#          'ContactDescription': 'Phone'}],
#        'PostalAddress': {'AddressLine': ['The Rufus Centre, Steppingley Road'],
#         'BuildingNumber': 'Barclays Bank',
#         'StreetName': 'Local - Flitwick',
#         'TownName': 'Flitwick',
#         'CountrySubDivision': ['Bedfordshire'],
#         'Country': 'UK',
#         'PostCode': 'MK45 1AH',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '52.01003720',
#           'Longitude': '-0.51042970'}}}},
#       {'Identification': 'UK-B-20057400',
#        'SequenceNumber': '0',
#        'Name': 'Barclays Bank',
#        'Type': 'Physical',
#        'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/bedfordshire/UK-B-20057400.jpg',
#        'CustomerSegment': ['Private',
#         'SME',
#         'Premier',
#         'Select',
#         'Wealth',
#         'Corporate',
#         'Business',
#         'Personal'],
#        'ServiceAndFacility': ['SaturdayCounterService'],
#        'Accessibility': ['WheelchairAccess',
#         'LevelAccess',
#         'AudioCashMachine',
#         'AutomaticDoors',
#         'LowerLevelCounter'],
#        'OtherAccessibility': [{'Name': 'Hearing induction loop',
#          'Description': 'Hearing induction loop'}],
#        'OtherServiceAndFacility': [{'Name': 'External ATM with deposit',
#          'Description': 'External ATM with deposit'},
#         {'Name': 'InternalAtmAudio', 'Description': 'InternalAtmAudio'},
#         {'Name': 'ExternalAtmAudio', 'Description': 'ExternalAtmAudio'}],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '13:00'}]},
#           {'Name': 'Sunday',
#            'OpeningHours': [{'OpeningTime': '00:00',
#              'ClosingTime': '00:00'}]}]}},
#        'ContactInfo': [{'ContactContent': '+44-3457345345',
#          'ContactDescription': 'Phone'}],
#        'PostalAddress': {'AddressLine': ['111 High Street'],
#         'BuildingNumber': 'Barclays Bank',
#         'StreetName': 'Branch - Bedford',
#         'TownName': 'Bedford',
#         'CountrySubDivision': ['Bedfordshire'],
#         'Country': 'UK',
#         'PostCode': 'MK40 1NJ',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '52.13805870',
#           'Longitude': '-0.46669780'}}}},
#       {'Identification': 'UK-B-20539700',
#        'SequenceNumber': '0',
#        'Name': 'Barclays Bank',
#        'Type': 'Physical',
#        'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/bedfordshire/UK-B-20533000.jpg',
#        'CustomerSegment': ['Private',
#         'SME',
#         'Premier',
#         'Select',
#         'Wealth',
#         'Corporate',
#         'Business',
#         'Personal'],
#        'ServiceAndFacility': ['SaturdayCounterService',
#         'AccountVerificationService'],
#        'Accessibility': ['WheelchairAccess',
#         'LevelAccess',
#         'AudioCashMachine',
#         'AutomaticDoors'],
#        'OtherAccessibility': [{'Name': 'Hearing induction loop',
#          'Description': 'Hearing induction loop'}],
#        'OtherServiceAndFacility': [{'Name': 'External ATM with deposit',
#          'Description': 'External ATM with deposit'},
#         {'Name': 'ExternalAtmAudio', 'Description': 'ExternalAtmAudio'}],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '13:00'}]},
#           {'Name': 'Sunday',
#            'OpeningHours': [{'OpeningTime': '00:00',
#              'ClosingTime': '00:00'}]}]}},
#        'ContactInfo': [{'ContactContent': '+44-3457345345',
#          'ContactDescription': 'Phone'}],
#        'PostalAddress': {'AddressLine': ['28 George Street'],
#         'BuildingNumber': 'Barclays Bank',
#         'StreetName': 'Branch - Luton',
#         'TownName': 'Luton',
#         'CountrySubDivision': ['Bedfordshire'],
#         'Country': 'UK',
#         'PostCode': 'LU1 2AX',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.87850000',
#           'Longitude': '-0.41474500'}}}},
#       {'Identification': '66000316',
#        'SequenceNumber': '0',
#        'Name': 'Barclays Bank',
#        'Type': 'Physical',
#        'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/flex-images/Local Generic Image.jpg',
#        'CustomerSegment': ['Private',
#         'SME',
#         'Premier',
#         'Select',
#         'Wealth',
#         'Corporate',
#         'Business',
#         'Personal'],
#        'Accessibility': ['WheelchairAccess', 'InductionLoop'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Sunday',
#            'OpeningHours': [{'OpeningTime': '00:00',
#              'ClosingTime': '00:00'}]}]}},
#        'ContactInfo': [{'ContactContent': '+44-3457345345',
#          'ContactDescription': 'Phone'}],
#        'PostalAddress': {'AddressLine': ['Regus, Gainsborough House'],
#         'BuildingNumber': 'Barclays Bank',
#         'StreetName': 'Local - Windsor',
#         'TownName': '59-60 Thames Street, Windsor',
#         'CountrySubDivision': ['Berkshire'],
#         'Country': 'UK',
#         'PostCode': 'SL4 1TX',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.48545350',
#           'Longitude': '-0.60753370'}}}},
#       {'Identification': '66000310',
#        'SequenceNumber': '0',
#        'Name': 'Barclays Bank',
#        'Type': 'Physical',
#        'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/flex-images/local--q-z/Wokingham.jpg',
#        'CustomerSegment': ['Private',
#         'SME',
#         'Premier',
#         'Select',
#         'Wealth',
#         'Corporate',
#         'Business',
#         'Personal'],
#        'Accessibility': ['WheelchairAccess', 'InductionLoop'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:30'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:30'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:30'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:30'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Sunday',
#            'OpeningHours': [{'OpeningTime': '00:00',
#              'ClosingTime': '00:00'}]}]}},
#        'ContactInfo': [{'ContactContent': '+44-3457345345',
#          'ContactDescription': 'Phone'}],
#        'PostalAddress': {'AddressLine': ['Bradbury Centre, Rose Street'],
#         'BuildingNumber': 'Barclays Bank',
#         'StreetName': 'Local - Wokingham',
#         'TownName': 'Wokingham',
#         'CountrySubDivision': ['Berkshire'],
#         'Country': 'UK',
#         'PostCode': 'RG40 1XS',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.41171750',
#           'Longitude': '-0.83138670'}}}},
#       {'Identification': 'UK-B-20785805',
#        'SequenceNumber': '0',
#        'Name': 'Barclays Bank',
#        'Type': 'Physical',
#        'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/flex-images/Local Generic Image.jpg',
#        'CustomerSegment': ['Private',
#         'SME',
#         'Premier',
#         'Select',
#         'Wealth',
#         'Corporate',
#         'Business',
#         'Personal'],
#        'Accessibility': ['WheelchairAccess'],
#        'OtherAccessibility': [{'Name': 'Hearing induction loop',
#          'Description': 'Hearing induction loop'}],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '16:30'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '16:30'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '16:30'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '16:30'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Sunday',
#            'OpeningHours': [{'OpeningTime': '00:00',
#              'ClosingTime': '00:00'}]}]}},
#        'ContactInfo': [{'ContactContent': '+44-3457345345',
#          'ContactDescription': 'Phone'}],
#        'PostalAddress': {'AddressLine': ['MyWorkSpot, York House'],
#         'BuildingNumber': 'Barclays Bank',
#         'StreetName': 'Local - Maidenhead',
#         'TownName': '18 York Road, Maidenhead',
#         'CountrySubDivision': ['Berkshire'],
#         'Country': 'UK',
#         'PostCode': 'SL6 1SF',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.52037530',
#           'Longitude': '-0.71991350'}}}},
#       {'Identification': 'UK-B-20117400',
#        'SequenceNumber': '0',
#        'Name': 'Barclays Bank',
#        'Type': 'Physical',
#        'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/berkshire/UK-B-20117400.jpg',
#        'CustomerSegment': ['Private',
#         'SME',
#         'Premier',
#         'Select',
#         'Wealth',
#         'Corporate',
#         'Business',
#         'Personal'],
#        'ServiceAndFacility': ['SaturdayCounterService'],
#        'Accessibility': ['WheelchairAccess',
#         'LevelAccess',
#         'AudioCashMachine',
#         'AutomaticDoors',
#         'ExternalRamp',
#         'InternalRamp'],
#        'OtherAccessibility': [{'Name': 'Accessible interview room',
#          'Description': 'Accessible interview room'},
#         {'Name': 'Hearing induction loop',
#          'Description': 'Hearing induction loop'}],
#        'OtherServiceAndFacility': [{'Name': 'ExternalAtmAudio',
#          'Description': 'ExternalAtmAudio'}],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '13:00'}]},
#           {'Name': 'Sunday',
#            'OpeningHours': [{'OpeningTime': '00:00',
#              'ClosingTime': '00:00'}]}]}},
#        'ContactInfo': [{'ContactContent': '+44-3457345345',
#          'ContactDescription': 'Phone'}],
#        'PostalAddress': {'AddressLine': ['1 High Street'],
#         'BuildingNumber': 'Barclays Bank',
#         'StreetName': 'Branch - Bracknell',
#         'TownName': 'Bracknell',
#         'CountrySubDivision': ['Berkshire'],
#         'Country': 'UK',
#         'PostCode': 'RG12 1DR',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.41612680',
#           'Longitude': '-0.74723480'}}}},
#       {'Identification': 'UK-B-20591400',
#        'SequenceNumber': '0',
#        'Name': 'Barclays Bank',
#        'Type': 'Physical',
#        'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/berkshire/UK-B-20591400.jpg',
#        'CustomerSegment': ['Private',
#         'SME',
#         'Premier',
#         'Select',
#         'Wealth',
#         'Corporate',
#         'Business',
#         'Personal'],
#        'ServiceAndFacility': ['SaturdayCounterService'],
#        'Accessibility': ['WheelchairAccess',
#         'LevelAccess',
#         'AudioCashMachine',
#         'AutomaticDoors',
#         'LowerLevelCounter'],
#        'OtherAccessibility': [{'Name': 'Hearing induction loop',
#          'Description': 'Hearing induction loop'}],
#        'OtherServiceAndFacility': [{'Name': 'External ATM with deposit',
#          'Description': 'External ATM with deposit'},
#         {'Name': 'ExternalAtmAudio', 'Description': 'ExternalAtmAudio'}],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '13:00'}]},
#           {'Name': 'Sunday',
#            'OpeningHours': [{'OpeningTime': '00:00',
#              'ClosingTime': '00:00'}]}]}},
#        'ContactInfo': [{'ContactContent': '+44-3457345345',
#          'ContactDescription': 'Phone'}],
#        'PostalAddress': {'AddressLine': ['23 - 26 Parkway Centre'],
#         'BuildingNumber': 'Barclays Bank',
#         'StreetName': 'Branch - Newbury',
#         'TownName': 'Newbury',
#         'CountrySubDivision': ['Berkshire'],
#         'Country': 'UK',
#         'PostCode': 'RG14 1AY',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.40330000',
#           'Longitude': '-1.32409000'}}}},
#       {'Identification': 'UK-B-20710300',
#        'SequenceNumber': '0',
#        'Name': 'Barclays Bank',
#        'Type': 'Physical',
#        'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/berkshire/UK-B-20710300.jpg',
#        'CustomerSegment': ['Private',
#         'SME',
#         'Premier',
#         'Select',
#         'Wealth',
#         'Corporate',
#         'Business',
#         'Personal'],
#        'ServiceAndFacility': ['SaturdayCounterService'],
#        'Accessibility': ['WheelchairAccess',
#         'LevelAccess',
#         'AudioCashMachine',
#         'AutomaticDoors'],
#        'OtherAccessibility': [{'Name': 'Accessible interview room',
#          'Description': 'Accessible interview room'},
#         {'Name': 'Hearing induction loop',
#          'Description': 'Hearing induction loop'}],
#        'OtherServiceAndFacility': [{'Name': 'External ATM with deposit',
#          'Description': 'External ATM with deposit'},
#         {'Name': 'ExternalAtmAudio', 'Description': 'ExternalAtmAudio'}],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '13:00'}]},
#           {'Name': 'Sunday',
#            'OpeningHours': [{'OpeningTime': '00:00',
#              'ClosingTime': '00:00'}]}]}},
#        'ContactInfo': [{'ContactContent': '+44-3457345345',
#          'ContactDescription': 'Phone'}],
#        'PostalAddress': {'AddressLine': ['90-93 Broad Street'],
#         'BuildingNumber': 'Barclays Bank',
#         'StreetName': 'Branch - Reading',
#         'TownName': 'Reading',
#         'CountrySubDivision': ['Berkshire'],
#         'Country': 'UK',
#         'PostCode': 'RG1 2AP',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.45557400',
#           'Longitude': '-0.97415520'}}}},
#       {'Identification': 'UK-B-20785800',
#        'SequenceNumber': '0',
#        'Name': 'Barclays Bank',
#        'Type': 'Physical',
#        'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/berkshire/UK-B-20785800.jpg',
#        'CustomerSegment': ['Private',
#         'SME',
#         'Premier',
#         'Select',
#         'Wealth',
#         'Corporate',
#         'Business',
#         'Personal'],
#        'ServiceAndFacility': ['SaturdayCounterService'],
#        'Accessibility': ['WheelchairAccess',
#         'LevelAccess',
#         'AudioCashMachine',
#         'AutomaticDoors'],
#        'OtherAccessibility': [{'Name': 'Accessible interview room',
#          'Description': 'Accessible interview room'},
#         {'Name': 'Hearing induction loop',
#          'Description': 'Hearing induction loop'}],
#        'OtherServiceAndFacility': [{'Name': 'External ATM with deposit',
#          'Description': 'External ATM with deposit'},
#         {'Name': 'ExternalAtmAudio', 'Description': 'ExternalAtmAudio'}],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '13:00'}]},
#           {'Name': 'Sunday',
#            'OpeningHours': [{'OpeningTime': '00:00',
#              'ClosingTime': '00:00'}]}]}},
#        'ContactInfo': [{'ContactContent': '+44-3457345345',
#          'ContactDescription': 'Phone'}],
#        'PostalAddress': {'AddressLine': ['1 Queensmere'],
#         'BuildingNumber': 'Barclays Bank',
#         'StreetName': 'Branch - Slough',
#         'TownName': 'Slough',
#         'CountrySubDivision': ['Berkshire'],
#         'Country': 'UK',
#         'PostCode': 'SL1 1DT',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.50910000',
#           'Longitude': '-0.59006400'}}}},
#       {'Identification': '66000283',
#        'SequenceNumber': '0',
#        'Name': 'Barclays Bank',
#        'Type': 'Physical',
#        'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/flex-images/Local Generic Image.jpg',
#        'CustomerSegment': ['Private',
#         'SME',
#         'Premier',
#         'Select',
#         'Wealth',
#         'Corporate',
#         'Business',
#         'Personal'],
#        'Accessibility': ['WheelchairAccess'],
#        'OtherAccessibility': [{'Name': 'Hearing induction loop',
#          'Description': 'Hearing induction loop'}],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '16:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '16:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Sunday',
#            'OpeningHours': [{'OpeningTime': '00:00',
#              'ClosingTime': '00:00'}]}]}},
#        'ContactInfo': [{'ContactContent': '+44-3457345345',
#          'ContactDescription': 'Phone'}],
#        'PostalAddress': {'AddressLine': ['The Park Centre, High Street'],
#         'BuildingNumber': 'Barclays Bank',
#         'StreetName': 'Local - Bristol Kingswood',
#         'TownName': 'Kingswood',
#         'CountrySubDivision': ['Bristol'],
#         'Country': 'UK',
#         'PostCode': 'BS15 4AR',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.46186470',
#           'Longitude': '-2.49954460'}}}},
#       {'Identification': 'UK-B-20133403',
#        'SequenceNumber': '0',
#        'Name': 'Barclays Bank',
#        'Type': 'Physical',
#        'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/flex-images/Local Generic Image.jpg',
#        'CustomerSegment': ['Private',
#         'SME',
#         'Premier',
#         'Select',
#         'Wealth',
#         'Corporate',
#         'Business',
#         'Personal'],
#        'Accessibility': ['WheelchairAccess'],
#        'OtherAccessibility': [{'Name': 'Hearing induction loop',
#          'Description': 'Hearing induction loop'}],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '16:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '16:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Sunday',
#            'OpeningHours': [{'OpeningTime': '00:00',
#              'ClosingTime': '00:00'}]}]}},
#        'ContactInfo': [{'ContactContent': '+44-3457345345',
#          'ContactDescription': 'Phone'}],
#        'PostalAddress': {'AddressLine': ['Greenway Centre, Doncaster Road'],
#         'BuildingNumber': 'Barclays Bank',
#         'StreetName': 'Local - Westbury on Trym',
#         'TownName': 'Westbury-on-Trym',
#         'CountrySubDivision': ['Bristol'],
#         'Country': 'UK',
#         'PostCode': 'BS10 5PY',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.50007760',
#           'Longitude': '-2.60802650'}}}},
#       {'Identification': 'UK-B-20136702',
#        'SequenceNumber': '0',
#        'Name': 'Barclays Bank',
#        'Type': 'Physical',
#        'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/bristol/UK-B-20134202.jpg',
#        'CustomerSegment': ['Private',
#         'SME',
#         'Premier',
#         'Select',
#         'Wealth',
#         'Corporate',
#         'Business',
#         'Personal'],
#        'ServiceAndFacility': ['SaturdayCounterService',
#         'AccountVerificationService'],
#        'Accessibility': ['WheelchairAccess',
#         'LevelAccess',
#         'AudioCashMachine',
#         'AutomaticDoors'],
#        'OtherAccessibility': [{'Name': 'Accessible interview room',
#          'Description': 'Accessible interview room'},
#         {'Name': 'Hearing induction loop',
#          'Description': 'Hearing induction loop'}],
#        'OtherServiceAndFacility': [{'Name': 'External ATM with deposit',
#          'Description': 'External ATM with deposit'},
#         {'Name': 'ExternalAtmAudio', 'Description': 'ExternalAtmAudio'}],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '13:00'}]},
#           {'Name': 'Sunday',
#            'OpeningHours': [{'OpeningTime': '00:00',
#              'ClosingTime': '00:00'}]}]}},
#        'ContactInfo': [{'ContactContent': '+44-3457345345',
#          'ContactDescription': 'Phone'}],
#        'PostalAddress': {'AddressLine': ['55 Broadmead'],
#         'BuildingNumber': 'Barclays Bank',
#         'StreetName': 'Branch - Bristol Broadmead',
#         'TownName': 'Bristol',
#         'Country': 'UK',
#         'PostCode': 'BS1 3EA',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.45739180',
#           'Longitude': '-2.58948010'}}}},
#       {'Identification': '66000332',
#        'SequenceNumber': '0',
#        'Name': 'Barclays Bank',
#        'Type': 'Physical',
#        'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/flex-images/Local Generic Image.jpg',
#        'CustomerSegment': ['Private',
#         'SME',
#         'Premier',
#         'Select',
#         'Wealth',
#         'Corporate',
#         'Business',
#         'Personal'],
#        'Accessibility': ['InductionLoop', 'WheelchairAccess'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '14:30'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '14:30'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '14:30'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '14:30'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Sunday',
#            'OpeningHours': [{'OpeningTime': '00:00',
#              'ClosingTime': '00:00'}]}]}},
#        'ContactInfo': [{'ContactContent': '+44-3457345345',
#          'ContactDescription': 'Phone'}],
#        'PostalAddress': {'AddressLine': ['Spaces, Room 112, Building 1, Chalfont Park'],
#         'BuildingNumber': 'Barclays Bank',
#         'StreetName': 'Local - Chalfont St. Peter',
#         'TownName': 'Chalfont St Peter, Gerrards Cross',
#         'CountrySubDivision': ['Buckinghamshire'],
#         'Country': 'UK',
#         'PostCode': 'SL9 0BG',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.59666690',
#           'Longitude': '-0.54600910'}}}},
#       {'Identification': '66000058',
#        'SequenceNumber': '0',
#        'Name': 'Barclays Bank',
#        'Type': 'Physical',
#        'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/flex-images/Local Generic Image.jpg',
#        'CustomerSegment': ['Private',
#         'SME',
#         'Premier',
#         'Select',
#         'Wealth',
#         'Corporate',
#         'Business',
#         'Personal'],
#        'Accessibility': ['InductionLoop', 'WheelchairAccess'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '10:00', 'ClosingTime': '14:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Sunday',
#            'OpeningHours': [{'OpeningTime': '00:00',
#              'ClosingTime': '00:00'}]}]}},
#        'ContactInfo': [{'ContactContent': '+44-3457345345',
#          'ContactDescription': 'Phone'}],
#        'PostalAddress': {'AddressLine': ['The Library, Institute Road'],
#         'BuildingNumber': 'Barclays Bank',
#         'StreetName': 'Local - Marlow',
#         'TownName': 'Marlow',
#         'CountrySubDivision': ['Buckinghamshire'],
#         'Country': 'UK',
#         'PostCode': 'SL7 1BL',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.57070466',
#           'Longitude': '-0.77424529'}}}},
#       {'Identification': '66000069',
#        'SequenceNumber': '0',
#        'Name': 'Barclays Bank',
#        'Type': 'Physical',
#        'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/flex-images/Local Generic Image.jpg',
#        'CustomerSegment': ['Private',
#         'SME',
#         'Premier',
#         'Select',
#         'Wealth',
#         'Corporate',
#         'Business',
#         'Personal'],
#        'Accessibility': ['WheelchairAccess', 'InductionLoop'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '16:30'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Sunday',
#            'OpeningHours': [{'OpeningTime': '00:00',
#              'ClosingTime': '00:00'}]}]}},
#        'ContactInfo': [{'ContactContent': '+44-3457345345',
#          'ContactDescription': 'Phone'}],
#        'PostalAddress': {'AddressLine': ['The Library'],
#         'BuildingNumber': 'Barclays Bank',
#         'StreetName': 'Local - Beaconsfield',
#         'TownName': 'Reynolds Road',
#         'CountrySubDivision': ['Beaconsfield'],
#         'Country': 'UK',
#         'PostCode': 'HP9 2NJ',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.61289880',
#           'Longitude': '-0.65055730'}}}},
#       {'Identification': '66000183',
#        'SequenceNumber': '0',
#        'Name': 'Barclays Bank',
#        'Type': 'Physical',
#        'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/flex-images/Local Generic Image.jpg',
#        'CustomerSegment': ['Private',
#         'SME',
#         'Premier',
#         'Select',
#         'Wealth',
#         'Corporate',
#         'Business',
#         'Personal'],
#        'Accessibility': ['InductionLoop', 'WheelchairAccess'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '16:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '16:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '16:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Sunday',
#            'OpeningHours': [{'OpeningTime': '00:00',
#              'ClosingTime': '00:00'}]}]}},
#        'ContactInfo': [{'ContactContent': '+44-3457345345',
#          'ContactDescription': 'Phone'}],
#        'PostalAddress': {'AddressLine': ['Unit 1A, Chiltern Business Centre, 63-65 Woodside Road'],
#         'BuildingNumber': 'Barclays Bank',
#         'StreetName': 'Local - Amersham',
#         'TownName': 'Amersham',
#         'CountrySubDivision': ['Buckinghamshire'],
#         'Country': 'UK',
#         'PostCode': 'HP6 6AA',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.67775160',
#           'Longitude': '-0.60345190'}}}},
#       {'Identification': 'UK-B-20031800',
#        'SequenceNumber': '0',
#        'Name': 'Barclays Bank',
#        'Type': 'Physical',
#        'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/buckinghamshire/UK-B-20031800.jpg',
#        'CustomerSegment': ['Private',
#         'SME',
#         'Premier',
#         'Select',
#         'Wealth',
#         'Corporate',
#         'Business',
#         'Personal'],
#        'ServiceAndFacility': ['SaturdayCounterService',
#         'AccountVerificationService'],
#        'Accessibility': ['WheelchairAccess',
#         'AudioCashMachine',
#         'AutomaticDoors',
#         'ExternalRamp',
#         'LowerLevelCounter'],
#        'OtherAccessibility': [{'Name': 'Accessible interview room',
#          'Description': 'Accessible interview room'},
#         {'Name': 'Hearing induction loop',
#          'Description': 'Hearing induction loop'}],
#        'OtherServiceAndFacility': [{'Name': 'External ATM with deposit',
#          'Description': 'External ATM with deposit'},
#         {'Name': 'ExternalAtmAudio', 'Description': 'ExternalAtmAudio'}],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '13:00'}]},
#           {'Name': 'Sunday',
#            'OpeningHours': [{'OpeningTime': '00:00',
#              'ClosingTime': '00:00'}]}]}},
#        'ContactInfo': [{'ContactContent': '+44-3457345345',
#          'ContactDescription': 'Phone'}],
#        'PostalAddress': {'AddressLine': ['34 Market Square'],
#         'BuildingNumber': 'Barclays Bank',
#         'StreetName': 'Branch - Aylesbury',
#         'TownName': 'Aylesbury',
#         'CountrySubDivision': ['Buckinghamshire'],
#         'Country': 'UK',
#         'PostCode': 'HP20 1TW',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.81589760',
#           'Longitude': '-0.81198150'}}}},
#       {'Identification': '66000227',
#        'SequenceNumber': '0',
#        'Name': 'Barclays Bank',
#        'Type': 'Physical',
#        'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/flex-images/Local Generic Image.jpg',
#        'CustomerSegment': ['Private',
#         'SME',
#         'Premier',
#         'Select',
#         'Wealth',
#         'Corporate',
#         'Business',
#         'Personal'],
#        'Accessibility': ['WheelchairAccess', 'InductionLoop'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '14:30'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '14:30'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '14:30'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Sunday',
#            'OpeningHours': [{'OpeningTime': '00:00',
#              'ClosingTime': '00:00'}]}]}},
#        'ContactInfo': [{'ContactContent': '+44-3457345345',
#          'ContactDescription': 'Phone'}],
#        'PostalAddress': {'AddressLine': ['Frosts Garden Centre, Newport Road'],
#         'BuildingNumber': 'Barclays Bank',
#         'StreetName': 'Local - Woburn Sands',
#         'TownName': 'Woburn Sands, Milton Keynes',
#         'CountrySubDivision': ['Buckinghamshire'],
#         'Country': 'UK',
#         'PostCode': 'MK17 8UE',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '52.02088710',
#           'Longitude': '-0.65916090'}}}},
#       {'Identification': '66000135',
#        'SequenceNumber': '0',
#        'Name': 'Barclays Bank',
#        'Type': 'Physical',
#        'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/flex-images/Local Generic Image.jpg',
#        'CustomerSegment': ['Private',
#         'SME',
#         'Premier',
#         'Select',
#         'Wealth',
#         'Corporate',
#         'Business',
#         'Personal'],
#        'Accessibility': ['InductionLoop', 'WheelchairAccess'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '14:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Sunday',
#            'OpeningHours': [{'OpeningTime': '00:00',
#              'ClosingTime': '00:00'}]}]}},
#        'ContactInfo': [{'ContactContent': '+44-3457345345',
#          'ContactDescription': 'Phone'}],
#        'PostalAddress': {'AddressLine': ['Bletchley Leisure Centre, Princes Way'],
#         'BuildingNumber': 'Barclays Bank',
#         'StreetName': 'Local - Bletchley',
#         'TownName': 'Fenny Stratford, Bletchley',
#         'CountrySubDivision': ['Buckinghamshire'],
#         'Country': 'UK',
#         'PostCode': 'MK2 2HQ',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.99633928',
#           'Longitude': '-0.72729234'}}}},
#       {'Identification': 'UK-B-20407100',
#        'SequenceNumber': '0',
#        'Name': 'Barclays Bank',
#        'Type': 'Physical',
#        'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/buckinghamshire/UK-B-20407100.jpg',
#        'CustomerSegment': ['Private',
#         'SME',
#         'Premier',
#         'Select',
#         'Wealth',
#         'Corporate',
#         'Business',
#         'Personal'],
#        'ServiceAndFacility': ['SaturdayCounterService',
#         'AccountVerificationService'],
#        'Accessibility': ['WheelchairAccess',
#         'LevelAccess',
#         'AudioCashMachine',
#         'AutomaticDoors',
#         'InternalRamp'],
#        'OtherAccessibility': [{'Name': 'Accessible interview room',
#          'Description': 'Accessible interview room'},
#         {'Name': 'Hearing induction loop',
#          'Description': 'Hearing induction loop'}],
#        'OtherServiceAndFacility': [{'Name': 'External ATM with deposit',
#          'Description': 'External ATM with deposit'},
#         {'Name': 'ExternalAtmAudio', 'Description': 'ExternalAtmAudio'}],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '13:00'}]},
#           {'Name': 'Sunday',
#            'OpeningHours': [{'OpeningTime': '00:00',
#              'ClosingTime': '00:00'}]}]}},
#        'ContactInfo': [{'ContactContent': '+44-3457345345',
#          'ContactDescription': 'Phone'}],
#        'PostalAddress': {'AddressLine': ['16 High Street'],
#         'BuildingNumber': 'Barclays Bank',
#         'StreetName': 'Branch - High Wycombe',
#         'TownName': 'High Wycombe',
#         'CountrySubDivision': ['Buckinghamshire'],
#         'Country': 'UK',
#         'PostCode': 'HP11 2BE',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.62878440',
#           'Longitude': '-0.74881270'}}}},
#       {'Identification': 'UK-B-20574001',
#        'SequenceNumber': '0',
#        'Name': 'Barclays Bank',
#        'Type': 'Physical',
#        'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/buckinghamshire/UK-B-20574001.jpg',
#        'CustomerSegment': ['Private',
#         'SME',
#         'Premier',
#         'Select',
#         'Wealth',
# ...
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Sunday',
#            'OpeningHours': [{'OpeningTime': '00:00',
#              'ClosingTime': '00:00'}]}]}},
#        'ContactInfo': [{'ContactContent': '+44-3457345345',
#          'ContactDescription': 'Phone'}],
#        'PostalAddress': {'AddressLine': ['Market Place'],
#         'BuildingNumber': 'Barclays Bank',
#         'StreetName': 'Banking Hub - Sidmouth',
#         'TownName': 'Sidmouth',
#         'CountrySubDivision': ['Devon'],
#         'Country': 'UK',
#         'PostCode': 'EX10 8AR',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '50.68081750',
#           'Longitude': '-3.23653040'}}}},
#       {'Identification': '22000047',
#        'SequenceNumber': '0',
#        'Name': 'Barclays bank',
#        'Type': '',
#        'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/flex-images/CAUK_BankingHub_Logo_Tile for web (002.png',
#        'CustomerSegment': ['Private',
#         'SME',
#         'Premier',
#         'Select',
#         'Wealth',
#         'Corporate',
#         'Business',
#         'Personal'],
#        'Accessibility': ['WheelchairAccess', 'InductionLoop'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Sunday',
#            'OpeningHours': [{'OpeningTime': '00:00',
#              'ClosingTime': '00:00'}]}]}},
#        'ContactInfo': [{'ContactContent': '+44-3457345345',
#          'ContactDescription': 'Phone'}],
#        'PostalAddress': {'AddressLine': ['43 High Street'],
#         'BuildingNumber': 'Barclays Bank',
#         'StreetName': 'Banking Hub - Oakham',
#         'TownName': 'Oakham',
#         'CountrySubDivision': ['Rutland'],
#         'Country': 'UK',
#         'PostCode': 'LE15 6AJ ',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '52.67004220',
#           'Longitude': '-0.73029020'}}}},
#       {'Identification': '22000049',
#        'SequenceNumber': '0',
#        'Name': 'Barclays bank',
#        'Type': '',
#        'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/flex-images/CAUK_BankingHub_Logo_Tile for web (002.png',
#        'CustomerSegment': ['Private',
#         'SME',
#         'Premier',
#         'Select',
#         'Wealth',
#         'Corporate',
#         'Business',
#         'Personal'],
#        'Accessibility': ['WheelchairAccess'],
#        'OtherAccessibility': [{'Name': 'Hearing induction loop',
#          'Description': 'Hearing induction loop'}],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Sunday',
#            'OpeningHours': [{'OpeningTime': '00:00',
#              'ClosingTime': '00:00'}]}]}},
#        'ContactInfo': [{'ContactContent': '+44-3457345345',
#          'ContactDescription': 'Phone'}],
#        'PostalAddress': {'AddressLine': ['77 John Street'],
#         'BuildingNumber': 'Barclays Bank',
#         'StreetName': 'Banking Hub - Porthcawl',
#         'TownName': 'Porthcawl',
#         'CountrySubDivision': ['Glamorgan'],
#         'Country': 'UK',
#         'PostCode': 'CF36 3AY',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.47868060',
#           'Longitude': '-3.70345000'}}}},
#       {'Identification': '22000048',
#        'SequenceNumber': '0',
#        'Name': 'Barclays bank',
#        'Type': 'Physical',
#        'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/flex-images/CAUK_BankingHub_Logo_Tile for web (002.png',
#        'CustomerSegment': ['Private',
#         'SME',
#         'Premier',
#         'Select',
#         'Wealth',
#         'Corporate',
#         'Business',
#         'Personal'],
#        'Accessibility': ['InductionLoop', 'WheelchairAccess'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Sunday',
#            'OpeningHours': [{'OpeningTime': '00:00',
#              'ClosingTime': '00:00'}]}]}},
#        'ContactInfo': [{'ContactContent': '+44-3457345345',
#          'ContactDescription': 'Phone'}],
#        'PostalAddress': {'AddressLine': ['15-17 Kirkgate'],
#         'BuildingNumber': 'Barclays Bank',
#         'StreetName': 'Banking Hub - Otley',
#         'TownName': 'Otley',
#         'CountrySubDivision': ['Yorkshire'],
#         'Country': 'UK',
#         'PostCode': 'LS21 3HN',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '53.90519740',
#           'Longitude': '-1.69445940'}}}},
#       {'Identification': '20078940',
#        'SequenceNumber': '0',
#        'Name': 'Barclays bank',
#        'Type': 'Mobile',
#        'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/flex-images/Barclays Electric Van 2.jpg',
#        'CustomerSegment': ['Private',
#         'SME',
#         'Premier',
#         'Select',
#         'Wealth',
#         'Corporate',
#         'Business',
#         'Personal'],
#        'ServiceAndFacility': ['SaturdayCounterService'],
#        'Accessibility': ['WheelchairAccess', 'ExternalRamp', 'InductionLoop'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '10:00', 'ClosingTime': '15:00'}]},
#           {'Name': 'Sunday',
#            'OpeningHours': [{'OpeningTime': '00:00',
#              'ClosingTime': '00:00'}]}]}},
#        'ContactInfo': [{'ContactContent': '+44-3457345345',
#          'ContactDescription': 'Phone'}],
#        'PostalAddress': {'AddressLine': ['Gallagher Retail Park, Axletree Way'],
#         'BuildingNumber': 'Barclays Bank',
#         'StreetName': 'Van - Wednesbury',
#         'TownName': 'Wednesbury',
#         'CountrySubDivision': ['West Midlands'],
#         'Country': 'UK',
#         'PostCode': 'WS10 9QY',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '52.56623367',
#           'Longitude': '-2.00852287'}}}},
#       {'Identification': '22000051',
#        'SequenceNumber': '0',
#        'Name': 'Barclays bank',
#        'Type': 'Physical',
#        'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/flex-images/CAUK_BankingHub_Logo_Tile for web (002.png',
#        'CustomerSegment': ['Private',
#         'SME',
#         'Premier',
#         'Select',
#         'Wealth',
#         'Corporate',
#         'Business',
#         'Personal'],
#        'Accessibility': ['WheelchairAccess', 'InductionLoop'],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '10:00', 'ClosingTime': '16:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '10:00', 'ClosingTime': '16:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '10:00', 'ClosingTime': '16:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '10:00', 'ClosingTime': '16:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '10:00', 'ClosingTime': '16:00'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Sunday',
#            'OpeningHours': [{'OpeningTime': '00:00',
#              'ClosingTime': '00:00'}]}]}},
#        'ContactInfo': [{'ContactContent': '+44-3457345345',
#          'ContactDescription': 'Phone'}],
#        'PostalAddress': {'AddressLine': ['Pershore Library, Church Street'],
#         'BuildingNumber': 'Barclays Bank',
#         'StreetName': 'Banking Hub - Pershore',
#         'TownName': 'Pershore',
#         'CountrySubDivision': ['Worcestershire'],
#         'Country': 'UK',
#         'PostCode': 'WR10 1DT',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '52.11144830',
#           'Longitude': '-2.07636130'}}}},
#       {'Identification': '22000053',
#        'SequenceNumber': '0',
#        'Name': 'Barclays bank',
#        'Type': '',
#        'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/flex-images/CAUK_BankingHub_Logo_Tile for web (002.png',
#        'CustomerSegment': ['Private',
#         'SME',
#         'Premier',
#         'Select',
#         'Wealth',
#         'Corporate',
#         'Business',
#         'Personal'],
#        'Accessibility': ['WheelchairAccess'],
#        'OtherAccessibility': [{'Name': 'Hearing induction loop',
#          'Description': 'Hearing induction loop'}],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Sunday',
#            'OpeningHours': [{'OpeningTime': '00:00',
#              'ClosingTime': '00:00'}]}]}},
#        'ContactInfo': [{'ContactContent': '+44-3457345345',
#          'ContactDescription': 'Phone'}],
#        'PostalAddress': {'AddressLine': ['8a Thoroughfare'],
#         'BuildingNumber': 'Barclays Bank',
#         'StreetName': 'Banking Hub - Harleston',
#         'TownName': 'Harleston',
#         'CountrySubDivision': ['Norfolk'],
#         'Country': 'UK',
#         'PostCode': 'IP20 9AX',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '52.40221520',
#           'Longitude': '1.29963280'}}}},
#       {'Identification': '22000045',
#        'SequenceNumber': '0',
#        'Name': 'Barclays bank',
#        'Type': 'Physical',
#        'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/flex-images/CAUK_BankingHub_Logo_Tile for web (002.png',
#        'CustomerSegment': ['Private',
#         'SME',
#         'Premier',
#         'Select',
#         'Wealth',
#         'Corporate',
#         'Business',
#         'Personal'],
#        'Accessibility': ['WheelchairAccess'],
#        'OtherAccessibility': [{'Name': 'Hearing induction loop',
#          'Description': 'Hearing induction loop'}],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '17:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '17:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '17:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '17:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '17:00'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Sunday',
#            'OpeningHours': [{'OpeningTime': '00:00',
#              'ClosingTime': '00:00'}]}]}},
#        'ContactInfo': [{'ContactContent': '+44-3457345345',
#          'ContactDescription': 'Phone'}],
#        'PostalAddress': {'AddressLine': ['Shirebrook Library, 19 Patchwork Row'],
#         'BuildingNumber': 'Barclays Bank',
#         'StreetName': 'Banking Hub - Shirebrook',
#         'TownName': 'Shirebrook ',
#         'CountrySubDivision': ['Derbyshire'],
#         'Country': 'UK',
#         'PostCode': 'NG20 8AL',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '53.20298790',
#           'Longitude': '-1.21399030'}}}},
#       {'Identification': '22000054',
#        'SequenceNumber': '0',
#        'Name': 'Barclays bank',
#        'Type': 'Physical',
#        'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/flex-images/CAUK_BankingHub_Logo_Tile for web (002.png',
#        'CustomerSegment': ['Private',
#         'SME',
#         'Premier',
#         'Select',
#         'Wealth',
#         'Corporate',
#         'Business',
#         'Personal'],
#        'Accessibility': ['WheelchairAccess'],
#        'OtherAccessibility': [{'Name': 'Hearing induction loop',
#          'Description': 'Hearing induction loop'}],
#        'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Tuesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Wednesday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Thursday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Friday',
#            'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#           {'Name': 'Saturday',
#            'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#           {'Name': 'Sunday',
#            'OpeningHours': [{'OpeningTime': '00:00',
#              'ClosingTime': '00:00'}]}]}},
#        'ContactInfo': [{'ContactContent': '+44-3457345345',
#          'ContactDescription': 'Phone'}],
#        'PostalAddress': {'AddressLine': ['Hometown Hub, Porthouse, 11 Exchange Street'],
#         'BuildingNumber': 'Barclays Bank',
#         'StreetName': 'Banking Hub - Jedburgh',
#         'TownName': 'Jedburgh',
#         'CountrySubDivision': ['Roxburghshire'],
#         'Country': 'UK',
#         'PostCode': 'TD8 6BH',
#         'GeoLocation': {'GeographicCoordinates': {'Latitude': '55.47814200',
#           'Longitude': '-2.55607080'}}}}]}]}]}

# %%
data.keys()
# Out:
# dict_keys(['meta', 'data'])

# %%
data['data'][0]['Brand']
# Out:
# [{'BrandName': 'Barclays UK',
#   'Branch': [{'Identification': 'UK-B-20031804',
#     'SequenceNumber': '0',
#     'Name': 'Barclays Bank',
#     'Type': 'Physical',
#     'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/flex-images/Local Generic Image.jpg',
#     'CustomerSegment': ['Private',
#      'SME',
#      'Premier',
#      'Select',
#      'Wealth',
#      'Corporate',
#      'Business',
#      'Personal'],
#     'Accessibility': ['WheelchairAccess', 'InductionLoop'],
#     'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Tuesday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '16:30'}]},
#        {'Name': 'Wednesday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Thursday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '16:30'}]},
#        {'Name': 'Friday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '16:30'}]},
#        {'Name': 'Saturday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Sunday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]}]}},
#     'ContactInfo': [{'ContactContent': '+44-3457345345',
#       'ContactDescription': 'Phone'}],
#     'PostalAddress': {'AddressLine': ['Leighton Buzzard Library Theatre'],
#      'BuildingNumber': 'Barclays Bank',
#      'StreetName': 'Local - Leighton Buzzard',
#      'TownName': 'Lake Street, Leighton Buzzard',
#      'CountrySubDivision': ['Bedfordshire'],
#      'Country': 'UK',
#      'PostCode': 'LU7 1RX',
#      'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.91501320',
#        'Longitude': '-0.65907430'}}}},
#    {'Identification': 'UK-B-20748104',
#     'SequenceNumber': '0',
#     'Name': 'Barclays Bank',
#     'Type': 'Physical',
#     'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/flex-images/local-a-h/Biggleswade.jpg',
#     'CustomerSegment': ['Private',
#      'SME',
#      'Premier',
#      'Select',
#      'Wealth',
#      'Corporate',
#      'Business',
#      'Personal'],
#     'Accessibility': ['WheelchairAccess', 'InductionLoop'],
#     'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Tuesday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '16:00'}]},
#        {'Name': 'Wednesday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '16:00'}]},
#        {'Name': 'Thursday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '16:00'}]},
#        {'Name': 'Friday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Saturday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Sunday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]}]}},
#     'ContactInfo': [{'ContactContent': '+44-3457345345',
#       'ContactDescription': 'Phone'}],
#     'PostalAddress': {'AddressLine': ['The Library, Chestnut Avenue'],
#      'BuildingNumber': 'Barclays Bank',
#      'StreetName': 'Local - Biggleswade',
#      'TownName': 'Biggleswade',
#      'CountrySubDivision': ['Bedfordshire'],
#      'Country': 'UK',
#      'PostCode': 'SG18 0LL',
#      'GeoLocation': {'GeographicCoordinates': {'Latitude': '52.08779860',
#        'Longitude': '-0.25938720'}}}},
#    {'Identification': '66000226',
#     'SequenceNumber': '0',
#     'Name': 'Barclays Bank',
#     'Type': 'Physical',
#     'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/flex-images/Local Generic Image.jpg',
#     'CustomerSegment': ['Private',
#      'SME',
#      'Premier',
#      'Select',
#      'Wealth',
#      'Corporate',
#      'Business',
#      'Personal'],
#     'Accessibility': ['InductionLoop', 'WheelchairAccess'],
#     'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '14:30'}]},
#        {'Name': 'Tuesday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Wednesday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Thursday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '14:30'}]},
#        {'Name': 'Friday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '14:30'}]},
#        {'Name': 'Saturday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Sunday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]}]}},
#     'ContactInfo': [{'ContactContent': '+44-3457345345',
#       'ContactDescription': 'Phone'}],
#     'PostalAddress': {'AddressLine': ['The Rufus Centre, Steppingley Road'],
#      'BuildingNumber': 'Barclays Bank',
#      'StreetName': 'Local - Flitwick',
#      'TownName': 'Flitwick',
#      'CountrySubDivision': ['Bedfordshire'],
#      'Country': 'UK',
#      'PostCode': 'MK45 1AH',
#      'GeoLocation': {'GeographicCoordinates': {'Latitude': '52.01003720',
#        'Longitude': '-0.51042970'}}}},
#    {'Identification': 'UK-B-20057400',
#     'SequenceNumber': '0',
#     'Name': 'Barclays Bank',
#     'Type': 'Physical',
#     'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/bedfordshire/UK-B-20057400.jpg',
#     'CustomerSegment': ['Private',
#      'SME',
#      'Premier',
#      'Select',
#      'Wealth',
#      'Corporate',
#      'Business',
#      'Personal'],
#     'ServiceAndFacility': ['SaturdayCounterService'],
#     'Accessibility': ['WheelchairAccess',
#      'LevelAccess',
#      'AudioCashMachine',
#      'AutomaticDoors',
#      'LowerLevelCounter'],
#     'OtherAccessibility': [{'Name': 'Hearing induction loop',
#       'Description': 'Hearing induction loop'}],
#     'OtherServiceAndFacility': [{'Name': 'External ATM with deposit',
#       'Description': 'External ATM with deposit'},
#      {'Name': 'InternalAtmAudio', 'Description': 'InternalAtmAudio'},
#      {'Name': 'ExternalAtmAudio', 'Description': 'ExternalAtmAudio'}],
#     'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Tuesday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Wednesday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Thursday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Friday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Saturday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '13:00'}]},
#        {'Name': 'Sunday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]}]}},
#     'ContactInfo': [{'ContactContent': '+44-3457345345',
#       'ContactDescription': 'Phone'}],
#     'PostalAddress': {'AddressLine': ['111 High Street'],
#      'BuildingNumber': 'Barclays Bank',
#      'StreetName': 'Branch - Bedford',
#      'TownName': 'Bedford',
#      'CountrySubDivision': ['Bedfordshire'],
#      'Country': 'UK',
#      'PostCode': 'MK40 1NJ',
#      'GeoLocation': {'GeographicCoordinates': {'Latitude': '52.13805870',
#        'Longitude': '-0.46669780'}}}},
#    {'Identification': 'UK-B-20539700',
#     'SequenceNumber': '0',
#     'Name': 'Barclays Bank',
#     'Type': 'Physical',
#     'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/bedfordshire/UK-B-20533000.jpg',
#     'CustomerSegment': ['Private',
#      'SME',
#      'Premier',
#      'Select',
#      'Wealth',
#      'Corporate',
#      'Business',
#      'Personal'],
#     'ServiceAndFacility': ['SaturdayCounterService',
#      'AccountVerificationService'],
#     'Accessibility': ['WheelchairAccess',
#      'LevelAccess',
#      'AudioCashMachine',
#      'AutomaticDoors'],
#     'OtherAccessibility': [{'Name': 'Hearing induction loop',
#       'Description': 'Hearing induction loop'}],
#     'OtherServiceAndFacility': [{'Name': 'External ATM with deposit',
#       'Description': 'External ATM with deposit'},
#      {'Name': 'ExternalAtmAudio', 'Description': 'ExternalAtmAudio'}],
#     'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Tuesday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Wednesday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Thursday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Friday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Saturday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '13:00'}]},
#        {'Name': 'Sunday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]}]}},
#     'ContactInfo': [{'ContactContent': '+44-3457345345',
#       'ContactDescription': 'Phone'}],
#     'PostalAddress': {'AddressLine': ['28 George Street'],
#      'BuildingNumber': 'Barclays Bank',
#      'StreetName': 'Branch - Luton',
#      'TownName': 'Luton',
#      'CountrySubDivision': ['Bedfordshire'],
#      'Country': 'UK',
#      'PostCode': 'LU1 2AX',
#      'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.87850000',
#        'Longitude': '-0.41474500'}}}},
#    {'Identification': '66000316',
#     'SequenceNumber': '0',
#     'Name': 'Barclays Bank',
#     'Type': 'Physical',
#     'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/flex-images/Local Generic Image.jpg',
#     'CustomerSegment': ['Private',
#      'SME',
#      'Premier',
#      'Select',
#      'Wealth',
#      'Corporate',
#      'Business',
#      'Personal'],
#     'Accessibility': ['WheelchairAccess', 'InductionLoop'],
#     'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Tuesday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Wednesday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Thursday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Friday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Saturday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Sunday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]}]}},
#     'ContactInfo': [{'ContactContent': '+44-3457345345',
#       'ContactDescription': 'Phone'}],
#     'PostalAddress': {'AddressLine': ['Regus, Gainsborough House'],
#      'BuildingNumber': 'Barclays Bank',
#      'StreetName': 'Local - Windsor',
#      'TownName': '59-60 Thames Street, Windsor',
#      'CountrySubDivision': ['Berkshire'],
#      'Country': 'UK',
#      'PostCode': 'SL4 1TX',
#      'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.48545350',
#        'Longitude': '-0.60753370'}}}},
#    {'Identification': '66000310',
#     'SequenceNumber': '0',
#     'Name': 'Barclays Bank',
#     'Type': 'Physical',
#     'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/flex-images/local--q-z/Wokingham.jpg',
#     'CustomerSegment': ['Private',
#      'SME',
#      'Premier',
#      'Select',
#      'Wealth',
#      'Corporate',
#      'Business',
#      'Personal'],
#     'Accessibility': ['WheelchairAccess', 'InductionLoop'],
#     'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Tuesday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:30'}]},
#        {'Name': 'Wednesday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:30'}]},
#        {'Name': 'Thursday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:30'}]},
#        {'Name': 'Friday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:30'}]},
#        {'Name': 'Saturday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Sunday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]}]}},
#     'ContactInfo': [{'ContactContent': '+44-3457345345',
#       'ContactDescription': 'Phone'}],
#     'PostalAddress': {'AddressLine': ['Bradbury Centre, Rose Street'],
#      'BuildingNumber': 'Barclays Bank',
#      'StreetName': 'Local - Wokingham',
#      'TownName': 'Wokingham',
#      'CountrySubDivision': ['Berkshire'],
#      'Country': 'UK',
#      'PostCode': 'RG40 1XS',
#      'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.41171750',
#        'Longitude': '-0.83138670'}}}},
#    {'Identification': 'UK-B-20785805',
#     'SequenceNumber': '0',
#     'Name': 'Barclays Bank',
#     'Type': 'Physical',
#     'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/flex-images/Local Generic Image.jpg',
#     'CustomerSegment': ['Private',
#      'SME',
#      'Premier',
#      'Select',
#      'Wealth',
#      'Corporate',
#      'Business',
#      'Personal'],
#     'Accessibility': ['WheelchairAccess'],
#     'OtherAccessibility': [{'Name': 'Hearing induction loop',
#       'Description': 'Hearing induction loop'}],
#     'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#         'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '16:30'}]},
#        {'Name': 'Tuesday',
#         'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '16:30'}]},
#        {'Name': 'Wednesday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Thursday',
#         'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '16:30'}]},
#        {'Name': 'Friday',
#         'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '16:30'}]},
#        {'Name': 'Saturday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Sunday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]}]}},
#     'ContactInfo': [{'ContactContent': '+44-3457345345',
#       'ContactDescription': 'Phone'}],
#     'PostalAddress': {'AddressLine': ['MyWorkSpot, York House'],
#      'BuildingNumber': 'Barclays Bank',
#      'StreetName': 'Local - Maidenhead',
#      'TownName': '18 York Road, Maidenhead',
#      'CountrySubDivision': ['Berkshire'],
#      'Country': 'UK',
#      'PostCode': 'SL6 1SF',
#      'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.52037530',
#        'Longitude': '-0.71991350'}}}},
#    {'Identification': 'UK-B-20117400',
#     'SequenceNumber': '0',
#     'Name': 'Barclays Bank',
#     'Type': 'Physical',
#     'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/berkshire/UK-B-20117400.jpg',
#     'CustomerSegment': ['Private',
#      'SME',
#      'Premier',
#      'Select',
#      'Wealth',
#      'Corporate',
#      'Business',
#      'Personal'],
#     'ServiceAndFacility': ['SaturdayCounterService'],
#     'Accessibility': ['WheelchairAccess',
#      'LevelAccess',
#      'AudioCashMachine',
#      'AutomaticDoors',
#      'ExternalRamp',
#      'InternalRamp'],
#     'OtherAccessibility': [{'Name': 'Accessible interview room',
#       'Description': 'Accessible interview room'},
#      {'Name': 'Hearing induction loop',
#       'Description': 'Hearing induction loop'}],
#     'OtherServiceAndFacility': [{'Name': 'ExternalAtmAudio',
#       'Description': 'ExternalAtmAudio'}],
#     'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Tuesday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Wednesday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Thursday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Friday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Saturday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '13:00'}]},
#        {'Name': 'Sunday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]}]}},
#     'ContactInfo': [{'ContactContent': '+44-3457345345',
#       'ContactDescription': 'Phone'}],
#     'PostalAddress': {'AddressLine': ['1 High Street'],
#      'BuildingNumber': 'Barclays Bank',
#      'StreetName': 'Branch - Bracknell',
#      'TownName': 'Bracknell',
#      'CountrySubDivision': ['Berkshire'],
#      'Country': 'UK',
#      'PostCode': 'RG12 1DR',
#      'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.41612680',
#        'Longitude': '-0.74723480'}}}},
#    {'Identification': 'UK-B-20591400',
#     'SequenceNumber': '0',
#     'Name': 'Barclays Bank',
#     'Type': 'Physical',
#     'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/berkshire/UK-B-20591400.jpg',
#     'CustomerSegment': ['Private',
#      'SME',
#      'Premier',
#      'Select',
#      'Wealth',
#      'Corporate',
#      'Business',
#      'Personal'],
#     'ServiceAndFacility': ['SaturdayCounterService'],
#     'Accessibility': ['WheelchairAccess',
#      'LevelAccess',
#      'AudioCashMachine',
#      'AutomaticDoors',
#      'LowerLevelCounter'],
#     'OtherAccessibility': [{'Name': 'Hearing induction loop',
#       'Description': 'Hearing induction loop'}],
#     'OtherServiceAndFacility': [{'Name': 'External ATM with deposit',
#       'Description': 'External ATM with deposit'},
#      {'Name': 'ExternalAtmAudio', 'Description': 'ExternalAtmAudio'}],
#     'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Tuesday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Wednesday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Thursday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Friday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Saturday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '13:00'}]},
#        {'Name': 'Sunday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]}]}},
#     'ContactInfo': [{'ContactContent': '+44-3457345345',
#       'ContactDescription': 'Phone'}],
#     'PostalAddress': {'AddressLine': ['23 - 26 Parkway Centre'],
#      'BuildingNumber': 'Barclays Bank',
#      'StreetName': 'Branch - Newbury',
#      'TownName': 'Newbury',
#      'CountrySubDivision': ['Berkshire'],
#      'Country': 'UK',
#      'PostCode': 'RG14 1AY',
#      'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.40330000',
#        'Longitude': '-1.32409000'}}}},
#    {'Identification': 'UK-B-20710300',
#     'SequenceNumber': '0',
#     'Name': 'Barclays Bank',
#     'Type': 'Physical',
#     'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/berkshire/UK-B-20710300.jpg',
#     'CustomerSegment': ['Private',
#      'SME',
#      'Premier',
#      'Select',
#      'Wealth',
#      'Corporate',
#      'Business',
#      'Personal'],
#     'ServiceAndFacility': ['SaturdayCounterService'],
#     'Accessibility': ['WheelchairAccess',
#      'LevelAccess',
#      'AudioCashMachine',
#      'AutomaticDoors'],
#     'OtherAccessibility': [{'Name': 'Accessible interview room',
#       'Description': 'Accessible interview room'},
#      {'Name': 'Hearing induction loop',
#       'Description': 'Hearing induction loop'}],
#     'OtherServiceAndFacility': [{'Name': 'External ATM with deposit',
#       'Description': 'External ATM with deposit'},
#      {'Name': 'ExternalAtmAudio', 'Description': 'ExternalAtmAudio'}],
#     'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Tuesday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Wednesday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Thursday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Friday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Saturday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '13:00'}]},
#        {'Name': 'Sunday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]}]}},
#     'ContactInfo': [{'ContactContent': '+44-3457345345',
#       'ContactDescription': 'Phone'}],
#     'PostalAddress': {'AddressLine': ['90-93 Broad Street'],
#      'BuildingNumber': 'Barclays Bank',
#      'StreetName': 'Branch - Reading',
#      'TownName': 'Reading',
#      'CountrySubDivision': ['Berkshire'],
#      'Country': 'UK',
#      'PostCode': 'RG1 2AP',
#      'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.45557400',
#        'Longitude': '-0.97415520'}}}},
#    {'Identification': 'UK-B-20785800',
#     'SequenceNumber': '0',
#     'Name': 'Barclays Bank',
#     'Type': 'Physical',
#     'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/berkshire/UK-B-20785800.jpg',
#     'CustomerSegment': ['Private',
#      'SME',
#      'Premier',
#      'Select',
#      'Wealth',
#      'Corporate',
#      'Business',
#      'Personal'],
#     'ServiceAndFacility': ['SaturdayCounterService'],
#     'Accessibility': ['WheelchairAccess',
#      'LevelAccess',
#      'AudioCashMachine',
#      'AutomaticDoors'],
#     'OtherAccessibility': [{'Name': 'Accessible interview room',
#       'Description': 'Accessible interview room'},
#      {'Name': 'Hearing induction loop',
#       'Description': 'Hearing induction loop'}],
#     'OtherServiceAndFacility': [{'Name': 'External ATM with deposit',
#       'Description': 'External ATM with deposit'},
#      {'Name': 'ExternalAtmAudio', 'Description': 'ExternalAtmAudio'}],
#     'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Tuesday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Wednesday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Thursday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Friday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Saturday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '13:00'}]},
#        {'Name': 'Sunday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]}]}},
#     'ContactInfo': [{'ContactContent': '+44-3457345345',
#       'ContactDescription': 'Phone'}],
#     'PostalAddress': {'AddressLine': ['1 Queensmere'],
#      'BuildingNumber': 'Barclays Bank',
#      'StreetName': 'Branch - Slough',
#      'TownName': 'Slough',
#      'CountrySubDivision': ['Berkshire'],
#      'Country': 'UK',
#      'PostCode': 'SL1 1DT',
#      'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.50910000',
#        'Longitude': '-0.59006400'}}}},
#    {'Identification': '66000283',
#     'SequenceNumber': '0',
#     'Name': 'Barclays Bank',
#     'Type': 'Physical',
#     'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/flex-images/Local Generic Image.jpg',
#     'CustomerSegment': ['Private',
#      'SME',
#      'Premier',
#      'Select',
#      'Wealth',
#      'Corporate',
#      'Business',
#      'Personal'],
#     'Accessibility': ['WheelchairAccess'],
#     'OtherAccessibility': [{'Name': 'Hearing induction loop',
#       'Description': 'Hearing induction loop'}],
#     'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Tuesday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '16:00'}]},
#        {'Name': 'Wednesday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Thursday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '16:00'}]},
#        {'Name': 'Friday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Saturday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Sunday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]}]}},
#     'ContactInfo': [{'ContactContent': '+44-3457345345',
#       'ContactDescription': 'Phone'}],
#     'PostalAddress': {'AddressLine': ['The Park Centre, High Street'],
#      'BuildingNumber': 'Barclays Bank',
#      'StreetName': 'Local - Bristol Kingswood',
#      'TownName': 'Kingswood',
#      'CountrySubDivision': ['Bristol'],
#      'Country': 'UK',
#      'PostCode': 'BS15 4AR',
#      'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.46186470',
#        'Longitude': '-2.49954460'}}}},
#    {'Identification': 'UK-B-20133403',
#     'SequenceNumber': '0',
#     'Name': 'Barclays Bank',
#     'Type': 'Physical',
#     'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/flex-images/Local Generic Image.jpg',
#     'CustomerSegment': ['Private',
#      'SME',
#      'Premier',
#      'Select',
#      'Wealth',
#      'Corporate',
#      'Business',
#      'Personal'],
#     'Accessibility': ['WheelchairAccess'],
#     'OtherAccessibility': [{'Name': 'Hearing induction loop',
#       'Description': 'Hearing induction loop'}],
#     'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '16:00'}]},
#        {'Name': 'Tuesday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Wednesday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Thursday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '16:00'}]},
#        {'Name': 'Friday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Saturday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Sunday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]}]}},
#     'ContactInfo': [{'ContactContent': '+44-3457345345',
#       'ContactDescription': 'Phone'}],
#     'PostalAddress': {'AddressLine': ['Greenway Centre, Doncaster Road'],
#      'BuildingNumber': 'Barclays Bank',
#      'StreetName': 'Local - Westbury on Trym',
#      'TownName': 'Westbury-on-Trym',
#      'CountrySubDivision': ['Bristol'],
#      'Country': 'UK',
#      'PostCode': 'BS10 5PY',
#      'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.50007760',
#        'Longitude': '-2.60802650'}}}},
#    {'Identification': 'UK-B-20136702',
#     'SequenceNumber': '0',
#     'Name': 'Barclays Bank',
#     'Type': 'Physical',
#     'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/bristol/UK-B-20134202.jpg',
#     'CustomerSegment': ['Private',
#      'SME',
#      'Premier',
#      'Select',
#      'Wealth',
#      'Corporate',
#      'Business',
#      'Personal'],
#     'ServiceAndFacility': ['SaturdayCounterService',
#      'AccountVerificationService'],
#     'Accessibility': ['WheelchairAccess',
#      'LevelAccess',
#      'AudioCashMachine',
#      'AutomaticDoors'],
#     'OtherAccessibility': [{'Name': 'Accessible interview room',
#       'Description': 'Accessible interview room'},
#      {'Name': 'Hearing induction loop',
#       'Description': 'Hearing induction loop'}],
#     'OtherServiceAndFacility': [{'Name': 'External ATM with deposit',
#       'Description': 'External ATM with deposit'},
#      {'Name': 'ExternalAtmAudio', 'Description': 'ExternalAtmAudio'}],
#     'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Tuesday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Wednesday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Thursday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Friday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Saturday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '13:00'}]},
#        {'Name': 'Sunday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]}]}},
#     'ContactInfo': [{'ContactContent': '+44-3457345345',
#       'ContactDescription': 'Phone'}],
#     'PostalAddress': {'AddressLine': ['55 Broadmead'],
#      'BuildingNumber': 'Barclays Bank',
#      'StreetName': 'Branch - Bristol Broadmead',
#      'TownName': 'Bristol',
#      'Country': 'UK',
#      'PostCode': 'BS1 3EA',
#      'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.45739180',
#        'Longitude': '-2.58948010'}}}},
#    {'Identification': '66000332',
#     'SequenceNumber': '0',
#     'Name': 'Barclays Bank',
#     'Type': 'Physical',
#     'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/flex-images/Local Generic Image.jpg',
#     'CustomerSegment': ['Private',
#      'SME',
#      'Premier',
#      'Select',
#      'Wealth',
#      'Corporate',
#      'Business',
#      'Personal'],
#     'Accessibility': ['InductionLoop', 'WheelchairAccess'],
#     'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '14:30'}]},
#        {'Name': 'Tuesday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '14:30'}]},
#        {'Name': 'Wednesday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Thursday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '14:30'}]},
#        {'Name': 'Friday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '14:30'}]},
#        {'Name': 'Saturday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Sunday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]}]}},
#     'ContactInfo': [{'ContactContent': '+44-3457345345',
#       'ContactDescription': 'Phone'}],
#     'PostalAddress': {'AddressLine': ['Spaces, Room 112, Building 1, Chalfont Park'],
#      'BuildingNumber': 'Barclays Bank',
#      'StreetName': 'Local - Chalfont St. Peter',
#      'TownName': 'Chalfont St Peter, Gerrards Cross',
#      'CountrySubDivision': ['Buckinghamshire'],
#      'Country': 'UK',
#      'PostCode': 'SL9 0BG',
#      'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.59666690',
#        'Longitude': '-0.54600910'}}}},
#    {'Identification': '66000058',
#     'SequenceNumber': '0',
#     'Name': 'Barclays Bank',
#     'Type': 'Physical',
#     'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/flex-images/Local Generic Image.jpg',
#     'CustomerSegment': ['Private',
#      'SME',
#      'Premier',
#      'Select',
#      'Wealth',
#      'Corporate',
#      'Business',
#      'Personal'],
#     'Accessibility': ['InductionLoop', 'WheelchairAccess'],
#     'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Tuesday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Wednesday',
#         'OpeningHours': [{'OpeningTime': '10:00', 'ClosingTime': '14:00'}]},
#        {'Name': 'Thursday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Friday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Saturday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Sunday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]}]}},
#     'ContactInfo': [{'ContactContent': '+44-3457345345',
#       'ContactDescription': 'Phone'}],
#     'PostalAddress': {'AddressLine': ['The Library, Institute Road'],
#      'BuildingNumber': 'Barclays Bank',
#      'StreetName': 'Local - Marlow',
#      'TownName': 'Marlow',
#      'CountrySubDivision': ['Buckinghamshire'],
#      'Country': 'UK',
#      'PostCode': 'SL7 1BL',
#      'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.57070466',
#        'Longitude': '-0.77424529'}}}},
#    {'Identification': '66000069',
#     'SequenceNumber': '0',
#     'Name': 'Barclays Bank',
#     'Type': 'Physical',
#     'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/flex-images/Local Generic Image.jpg',
#     'CustomerSegment': ['Private',
#      'SME',
#      'Premier',
#      'Select',
#      'Wealth',
#      'Corporate',
#      'Business',
#      'Personal'],
#     'Accessibility': ['WheelchairAccess', 'InductionLoop'],
#     'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Tuesday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Wednesday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Thursday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '16:30'}]},
#        {'Name': 'Friday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Saturday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Sunday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]}]}},
#     'ContactInfo': [{'ContactContent': '+44-3457345345',
#       'ContactDescription': 'Phone'}],
#     'PostalAddress': {'AddressLine': ['The Library'],
#      'BuildingNumber': 'Barclays Bank',
#      'StreetName': 'Local - Beaconsfield',
#      'TownName': 'Reynolds Road',
#      'CountrySubDivision': ['Beaconsfield'],
#      'Country': 'UK',
#      'PostCode': 'HP9 2NJ',
#      'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.61289880',
#        'Longitude': '-0.65055730'}}}},
#    {'Identification': '66000183',
#     'SequenceNumber': '0',
#     'Name': 'Barclays Bank',
#     'Type': 'Physical',
#     'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/flex-images/Local Generic Image.jpg',
#     'CustomerSegment': ['Private',
#      'SME',
#      'Premier',
#      'Select',
#      'Wealth',
#      'Corporate',
#      'Business',
#      'Personal'],
#     'Accessibility': ['InductionLoop', 'WheelchairAccess'],
#     'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '16:00'}]},
#        {'Name': 'Tuesday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '16:00'}]},
#        {'Name': 'Wednesday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '16:00'}]},
#        {'Name': 'Thursday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Friday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Saturday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Sunday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]}]}},
#     'ContactInfo': [{'ContactContent': '+44-3457345345',
#       'ContactDescription': 'Phone'}],
#     'PostalAddress': {'AddressLine': ['Unit 1A, Chiltern Business Centre, 63-65 Woodside Road'],
#      'BuildingNumber': 'Barclays Bank',
#      'StreetName': 'Local - Amersham',
#      'TownName': 'Amersham',
#      'CountrySubDivision': ['Buckinghamshire'],
#      'Country': 'UK',
#      'PostCode': 'HP6 6AA',
#      'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.67775160',
#        'Longitude': '-0.60345190'}}}},
#    {'Identification': 'UK-B-20031800',
#     'SequenceNumber': '0',
#     'Name': 'Barclays Bank',
#     'Type': 'Physical',
#     'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/buckinghamshire/UK-B-20031800.jpg',
#     'CustomerSegment': ['Private',
#      'SME',
#      'Premier',
#      'Select',
#      'Wealth',
#      'Corporate',
#      'Business',
#      'Personal'],
#     'ServiceAndFacility': ['SaturdayCounterService',
#      'AccountVerificationService'],
#     'Accessibility': ['WheelchairAccess',
#      'AudioCashMachine',
#      'AutomaticDoors',
#      'ExternalRamp',
#      'LowerLevelCounter'],
#     'OtherAccessibility': [{'Name': 'Accessible interview room',
#       'Description': 'Accessible interview room'},
#      {'Name': 'Hearing induction loop',
#       'Description': 'Hearing induction loop'}],
#     'OtherServiceAndFacility': [{'Name': 'External ATM with deposit',
#       'Description': 'External ATM with deposit'},
#      {'Name': 'ExternalAtmAudio', 'Description': 'ExternalAtmAudio'}],
#     'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Tuesday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Wednesday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Thursday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Friday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Saturday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '13:00'}]},
#        {'Name': 'Sunday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]}]}},
#     'ContactInfo': [{'ContactContent': '+44-3457345345',
#       'ContactDescription': 'Phone'}],
#     'PostalAddress': {'AddressLine': ['34 Market Square'],
#      'BuildingNumber': 'Barclays Bank',
#      'StreetName': 'Branch - Aylesbury',
#      'TownName': 'Aylesbury',
#      'CountrySubDivision': ['Buckinghamshire'],
#      'Country': 'UK',
#      'PostCode': 'HP20 1TW',
#      'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.81589760',
#        'Longitude': '-0.81198150'}}}},
#    {'Identification': '66000227',
#     'SequenceNumber': '0',
#     'Name': 'Barclays Bank',
#     'Type': 'Physical',
#     'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/flex-images/Local Generic Image.jpg',
#     'CustomerSegment': ['Private',
#      'SME',
#      'Premier',
#      'Select',
#      'Wealth',
#      'Corporate',
#      'Business',
#      'Personal'],
#     'Accessibility': ['WheelchairAccess', 'InductionLoop'],
#     'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#         'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '14:30'}]},
#        {'Name': 'Tuesday',
#         'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '14:30'}]},
#        {'Name': 'Wednesday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Thursday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Friday',
#         'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '14:30'}]},
#        {'Name': 'Saturday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Sunday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]}]}},
#     'ContactInfo': [{'ContactContent': '+44-3457345345',
#       'ContactDescription': 'Phone'}],
#     'PostalAddress': {'AddressLine': ['Frosts Garden Centre, Newport Road'],
#      'BuildingNumber': 'Barclays Bank',
#      'StreetName': 'Local - Woburn Sands',
#      'TownName': 'Woburn Sands, Milton Keynes',
#      'CountrySubDivision': ['Buckinghamshire'],
#      'Country': 'UK',
#      'PostCode': 'MK17 8UE',
#      'GeoLocation': {'GeographicCoordinates': {'Latitude': '52.02088710',
#        'Longitude': '-0.65916090'}}}},
#    {'Identification': '66000135',
#     'SequenceNumber': '0',
#     'Name': 'Barclays Bank',
#     'Type': 'Physical',
#     'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/flex-images/Local Generic Image.jpg',
#     'CustomerSegment': ['Private',
#      'SME',
#      'Premier',
#      'Select',
#      'Wealth',
#      'Corporate',
#      'Business',
#      'Personal'],
#     'Accessibility': ['InductionLoop', 'WheelchairAccess'],
#     'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Tuesday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Wednesday',
#         'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '14:00'}]},
#        {'Name': 'Thursday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Friday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Saturday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Sunday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]}]}},
#     'ContactInfo': [{'ContactContent': '+44-3457345345',
#       'ContactDescription': 'Phone'}],
#     'PostalAddress': {'AddressLine': ['Bletchley Leisure Centre, Princes Way'],
#      'BuildingNumber': 'Barclays Bank',
#      'StreetName': 'Local - Bletchley',
#      'TownName': 'Fenny Stratford, Bletchley',
#      'CountrySubDivision': ['Buckinghamshire'],
#      'Country': 'UK',
#      'PostCode': 'MK2 2HQ',
#      'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.99633928',
#        'Longitude': '-0.72729234'}}}},
#    {'Identification': 'UK-B-20407100',
#     'SequenceNumber': '0',
#     'Name': 'Barclays Bank',
#     'Type': 'Physical',
#     'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/buckinghamshire/UK-B-20407100.jpg',
#     'CustomerSegment': ['Private',
#      'SME',
#      'Premier',
#      'Select',
#      'Wealth',
#      'Corporate',
#      'Business',
#      'Personal'],
#     'ServiceAndFacility': ['SaturdayCounterService',
#      'AccountVerificationService'],
#     'Accessibility': ['WheelchairAccess',
#      'LevelAccess',
#      'AudioCashMachine',
#      'AutomaticDoors',
#      'InternalRamp'],
#     'OtherAccessibility': [{'Name': 'Accessible interview room',
#       'Description': 'Accessible interview room'},
#      {'Name': 'Hearing induction loop',
#       'Description': 'Hearing induction loop'}],
#     'OtherServiceAndFacility': [{'Name': 'External ATM with deposit',
#       'Description': 'External ATM with deposit'},
#      {'Name': 'ExternalAtmAudio', 'Description': 'ExternalAtmAudio'}],
#     'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Tuesday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Wednesday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Thursday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Friday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Saturday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '13:00'}]},
#        {'Name': 'Sunday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]}]}},
#     'ContactInfo': [{'ContactContent': '+44-3457345345',
#       'ContactDescription': 'Phone'}],
#     'PostalAddress': {'AddressLine': ['16 High Street'],
#      'BuildingNumber': 'Barclays Bank',
#      'StreetName': 'Branch - High Wycombe',
#      'TownName': 'High Wycombe',
#      'CountrySubDivision': ['Buckinghamshire'],
#      'Country': 'UK',
#      'PostCode': 'HP11 2BE',
#      'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.62878440',
#        'Longitude': '-0.74881270'}}}},
#    {'Identification': 'UK-B-20574001',
#     'SequenceNumber': '0',
#     'Name': 'Barclays Bank',
#     'Type': 'Physical',
#     'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/buckinghamshire/UK-B-20574001.jpg',
#     'CustomerSegment': ['Private',
#      'SME',
#      'Premier',
#      'Select',
#      'Wealth',
#      'Corporate',
#      'Business',
#      'Personal'],
#     'ServiceAndFacility': ['SaturdayCounterService'],
#     'Accessibility': ['WheelchairAccess',
#      'LevelAccess',
#      'AudioCashMachine',
#      'AutomaticDoors'],
#     'OtherAccessibility': [{'Name': 'Hearing induction loop',
#       'Description': 'Hearing induction loop'}],
#     'OtherServiceAndFacility': [{'Name': 'External ATM with deposit',
#       'Description': 'External ATM with deposit'},
#      {'Name': 'ExternalAtmAudio', 'Description': 'ExternalAtmAudio'}],
#     'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Tuesday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Wednesday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Thursday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Friday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '15:00'}]},
#        {'Name': 'Saturday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '13:00'}]},
#        {'Name': 'Sunday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]}]}},
#     'ContactInfo': [{'ContactContent': '+44-3457345345',
#       'ContactDescription': 'Phone'}],
#     'PostalAddress': {'AddressLine': ['9 Midsummer Place'],
#      'BuildingNumber': 'Barclays Bank',
#      'StreetName': 'Branch - Milton Keynes',
#      'TownName': 'Milton Keynes',
#      'CountrySubDivision': ['Buckinghamshire'],
#      'Country': 'UK',
#      'PostCode': 'MK9 3GB',
#      'GeoLocation': {'GeographicCoordinates': {'Latitude': '52.04101100',
#        'Longitude': '-0.75843660'}}}},
#    {'Identification': '66000240',
#     'SequenceNumber': '0',
#     'Name': 'Barclays Bank',
#     'Type': 'Physical',
#     'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/flex-images/Local Generic Image.jpg',
#     'CustomerSegment': ['Private',
#      'SME',
#      'Premier',
#      'Select',
#      'Wealth',
#      'Corporate',
#      'Business',
#      'Personal'],
#     'Accessibility': ['WheelchairAccess', 'InductionLoop'],
#     'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#         'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#        {'Name': 'Tuesday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Wednesday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Thursday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Friday',
#         'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#        {'Name': 'Saturday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Sunday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]}]}},
#     'ContactInfo': [{'ContactContent': '+44-3457345345',
#       'ContactDescription': 'Phone'}],
#     'PostalAddress': {'AddressLine': ['The Library, Glapthorn Road'],
#      'BuildingNumber': 'Barclays Bank',
#      'StreetName': 'Local - Oundle',
#      'TownName': 'Oundle, Peterborough',
#      'CountrySubDivision': ['Cambridgeshire'],
#      'Country': 'UK',
#      'PostCode': 'PE8 4JA',
#      'GeoLocation': {'GeographicCoordinates': {'Latitude': '52.48558330',
#        'Longitude': '-0.47229710'}}}},
#    {'Identification': '66000125',
#     'SequenceNumber': '0',
#     'Name': 'Barclays Bank',
#     'Type': 'Physical',
# ...
#      'PostCode': 'SK7 1AW',
#      'GeoLocation': {'GeographicCoordinates': {'Latitude': '53.35795440',
#        'Longitude': '-2.16639140'}}}},
#    {'Identification': '22000044',
#     'SequenceNumber': '0',
#     'Name': 'Barclays bank',
#     'Type': 'Physical',
#     'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/flex-images/CAUK_BankingHub_Logo_Tile for web (002.png',
#     'CustomerSegment': ['Private',
#      'SME',
#      'Premier',
#      'Select',
#      'Wealth',
#      'Corporate',
#      'Business',
#      'Personal'],
#     'Accessibility': ['InductionLoop', 'WheelchairAccess'],
#     'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#         'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#        {'Name': 'Tuesday',
#         'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#        {'Name': 'Wednesday',
#         'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#        {'Name': 'Thursday',
#         'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#        {'Name': 'Friday',
#         'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#        {'Name': 'Saturday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Sunday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]}]}},
#     'ContactInfo': [{'ContactContent': '+44-3457345345',
#       'ContactDescription': 'Phone'}],
#     'PostalAddress': {'AddressLine': ['Market Place'],
#      'BuildingNumber': 'Barclays Bank',
#      'StreetName': 'Banking Hub - Sidmouth',
#      'TownName': 'Sidmouth',
#      'CountrySubDivision': ['Devon'],
#      'Country': 'UK',
#      'PostCode': 'EX10 8AR',
#      'GeoLocation': {'GeographicCoordinates': {'Latitude': '50.68081750',
#        'Longitude': '-3.23653040'}}}},
#    {'Identification': '22000047',
#     'SequenceNumber': '0',
#     'Name': 'Barclays bank',
#     'Type': '',
#     'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/flex-images/CAUK_BankingHub_Logo_Tile for web (002.png',
#     'CustomerSegment': ['Private',
#      'SME',
#      'Premier',
#      'Select',
#      'Wealth',
#      'Corporate',
#      'Business',
#      'Personal'],
#     'Accessibility': ['WheelchairAccess', 'InductionLoop'],
#     'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#         'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#        {'Name': 'Tuesday',
#         'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#        {'Name': 'Wednesday',
#         'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#        {'Name': 'Thursday',
#         'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#        {'Name': 'Friday',
#         'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#        {'Name': 'Saturday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Sunday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]}]}},
#     'ContactInfo': [{'ContactContent': '+44-3457345345',
#       'ContactDescription': 'Phone'}],
#     'PostalAddress': {'AddressLine': ['43 High Street'],
#      'BuildingNumber': 'Barclays Bank',
#      'StreetName': 'Banking Hub - Oakham',
#      'TownName': 'Oakham',
#      'CountrySubDivision': ['Rutland'],
#      'Country': 'UK',
#      'PostCode': 'LE15 6AJ ',
#      'GeoLocation': {'GeographicCoordinates': {'Latitude': '52.67004220',
#        'Longitude': '-0.73029020'}}}},
#    {'Identification': '22000049',
#     'SequenceNumber': '0',
#     'Name': 'Barclays bank',
#     'Type': '',
#     'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/flex-images/CAUK_BankingHub_Logo_Tile for web (002.png',
#     'CustomerSegment': ['Private',
#      'SME',
#      'Premier',
#      'Select',
#      'Wealth',
#      'Corporate',
#      'Business',
#      'Personal'],
#     'Accessibility': ['WheelchairAccess'],
#     'OtherAccessibility': [{'Name': 'Hearing induction loop',
#       'Description': 'Hearing induction loop'}],
#     'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#         'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#        {'Name': 'Tuesday',
#         'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#        {'Name': 'Wednesday',
#         'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#        {'Name': 'Thursday',
#         'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#        {'Name': 'Friday',
#         'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#        {'Name': 'Saturday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Sunday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]}]}},
#     'ContactInfo': [{'ContactContent': '+44-3457345345',
#       'ContactDescription': 'Phone'}],
#     'PostalAddress': {'AddressLine': ['77 John Street'],
#      'BuildingNumber': 'Barclays Bank',
#      'StreetName': 'Banking Hub - Porthcawl',
#      'TownName': 'Porthcawl',
#      'CountrySubDivision': ['Glamorgan'],
#      'Country': 'UK',
#      'PostCode': 'CF36 3AY',
#      'GeoLocation': {'GeographicCoordinates': {'Latitude': '51.47868060',
#        'Longitude': '-3.70345000'}}}},
#    {'Identification': '22000048',
#     'SequenceNumber': '0',
#     'Name': 'Barclays bank',
#     'Type': 'Physical',
#     'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/flex-images/CAUK_BankingHub_Logo_Tile for web (002.png',
#     'CustomerSegment': ['Private',
#      'SME',
#      'Premier',
#      'Select',
#      'Wealth',
#      'Corporate',
#      'Business',
#      'Personal'],
#     'Accessibility': ['InductionLoop', 'WheelchairAccess'],
#     'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#         'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#        {'Name': 'Tuesday',
#         'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#        {'Name': 'Wednesday',
#         'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#        {'Name': 'Thursday',
#         'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#        {'Name': 'Friday',
#         'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#        {'Name': 'Saturday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Sunday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]}]}},
#     'ContactInfo': [{'ContactContent': '+44-3457345345',
#       'ContactDescription': 'Phone'}],
#     'PostalAddress': {'AddressLine': ['15-17 Kirkgate'],
#      'BuildingNumber': 'Barclays Bank',
#      'StreetName': 'Banking Hub - Otley',
#      'TownName': 'Otley',
#      'CountrySubDivision': ['Yorkshire'],
#      'Country': 'UK',
#      'PostCode': 'LS21 3HN',
#      'GeoLocation': {'GeographicCoordinates': {'Latitude': '53.90519740',
#        'Longitude': '-1.69445940'}}}},
#    {'Identification': '20078940',
#     'SequenceNumber': '0',
#     'Name': 'Barclays bank',
#     'Type': 'Mobile',
#     'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/flex-images/Barclays Electric Van 2.jpg',
#     'CustomerSegment': ['Private',
#      'SME',
#      'Premier',
#      'Select',
#      'Wealth',
#      'Corporate',
#      'Business',
#      'Personal'],
#     'ServiceAndFacility': ['SaturdayCounterService'],
#     'Accessibility': ['WheelchairAccess', 'ExternalRamp', 'InductionLoop'],
#     'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Tuesday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Wednesday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Thursday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Friday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Saturday',
#         'OpeningHours': [{'OpeningTime': '10:00', 'ClosingTime': '15:00'}]},
#        {'Name': 'Sunday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]}]}},
#     'ContactInfo': [{'ContactContent': '+44-3457345345',
#       'ContactDescription': 'Phone'}],
#     'PostalAddress': {'AddressLine': ['Gallagher Retail Park, Axletree Way'],
#      'BuildingNumber': 'Barclays Bank',
#      'StreetName': 'Van - Wednesbury',
#      'TownName': 'Wednesbury',
#      'CountrySubDivision': ['West Midlands'],
#      'Country': 'UK',
#      'PostCode': 'WS10 9QY',
#      'GeoLocation': {'GeographicCoordinates': {'Latitude': '52.56623367',
#        'Longitude': '-2.00852287'}}}},
#    {'Identification': '22000051',
#     'SequenceNumber': '0',
#     'Name': 'Barclays bank',
#     'Type': 'Physical',
#     'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/flex-images/CAUK_BankingHub_Logo_Tile for web (002.png',
#     'CustomerSegment': ['Private',
#      'SME',
#      'Premier',
#      'Select',
#      'Wealth',
#      'Corporate',
#      'Business',
#      'Personal'],
#     'Accessibility': ['WheelchairAccess', 'InductionLoop'],
#     'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#         'OpeningHours': [{'OpeningTime': '10:00', 'ClosingTime': '16:00'}]},
#        {'Name': 'Tuesday',
#         'OpeningHours': [{'OpeningTime': '10:00', 'ClosingTime': '16:00'}]},
#        {'Name': 'Wednesday',
#         'OpeningHours': [{'OpeningTime': '10:00', 'ClosingTime': '16:00'}]},
#        {'Name': 'Thursday',
#         'OpeningHours': [{'OpeningTime': '10:00', 'ClosingTime': '16:00'}]},
#        {'Name': 'Friday',
#         'OpeningHours': [{'OpeningTime': '10:00', 'ClosingTime': '16:00'}]},
#        {'Name': 'Saturday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Sunday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]}]}},
#     'ContactInfo': [{'ContactContent': '+44-3457345345',
#       'ContactDescription': 'Phone'}],
#     'PostalAddress': {'AddressLine': ['Pershore Library, Church Street'],
#      'BuildingNumber': 'Barclays Bank',
#      'StreetName': 'Banking Hub - Pershore',
#      'TownName': 'Pershore',
#      'CountrySubDivision': ['Worcestershire'],
#      'Country': 'UK',
#      'PostCode': 'WR10 1DT',
#      'GeoLocation': {'GeographicCoordinates': {'Latitude': '52.11144830',
#        'Longitude': '-2.07636130'}}}},
#    {'Identification': '22000053',
#     'SequenceNumber': '0',
#     'Name': 'Barclays bank',
#     'Type': '',
#     'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/flex-images/CAUK_BankingHub_Logo_Tile for web (002.png',
#     'CustomerSegment': ['Private',
#      'SME',
#      'Premier',
#      'Select',
#      'Wealth',
#      'Corporate',
#      'Business',
#      'Personal'],
#     'Accessibility': ['WheelchairAccess'],
#     'OtherAccessibility': [{'Name': 'Hearing induction loop',
#       'Description': 'Hearing induction loop'}],
#     'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#         'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#        {'Name': 'Tuesday',
#         'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#        {'Name': 'Wednesday',
#         'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#        {'Name': 'Thursday',
#         'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#        {'Name': 'Friday',
#         'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#        {'Name': 'Saturday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Sunday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]}]}},
#     'ContactInfo': [{'ContactContent': '+44-3457345345',
#       'ContactDescription': 'Phone'}],
#     'PostalAddress': {'AddressLine': ['8a Thoroughfare'],
#      'BuildingNumber': 'Barclays Bank',
#      'StreetName': 'Banking Hub - Harleston',
#      'TownName': 'Harleston',
#      'CountrySubDivision': ['Norfolk'],
#      'Country': 'UK',
#      'PostCode': 'IP20 9AX',
#      'GeoLocation': {'GeographicCoordinates': {'Latitude': '52.40221520',
#        'Longitude': '1.29963280'}}}},
#    {'Identification': '22000045',
#     'SequenceNumber': '0',
#     'Name': 'Barclays bank',
#     'Type': 'Physical',
#     'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/flex-images/CAUK_BankingHub_Logo_Tile for web (002.png',
#     'CustomerSegment': ['Private',
#      'SME',
#      'Premier',
#      'Select',
#      'Wealth',
#      'Corporate',
#      'Business',
#      'Personal'],
#     'Accessibility': ['WheelchairAccess'],
#     'OtherAccessibility': [{'Name': 'Hearing induction loop',
#       'Description': 'Hearing induction loop'}],
#     'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '17:00'}]},
#        {'Name': 'Tuesday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '17:00'}]},
#        {'Name': 'Wednesday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '17:00'}]},
#        {'Name': 'Thursday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '17:00'}]},
#        {'Name': 'Friday',
#         'OpeningHours': [{'OpeningTime': '09:30', 'ClosingTime': '17:00'}]},
#        {'Name': 'Saturday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Sunday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]}]}},
#     'ContactInfo': [{'ContactContent': '+44-3457345345',
#       'ContactDescription': 'Phone'}],
#     'PostalAddress': {'AddressLine': ['Shirebrook Library, 19 Patchwork Row'],
#      'BuildingNumber': 'Barclays Bank',
#      'StreetName': 'Banking Hub - Shirebrook',
#      'TownName': 'Shirebrook ',
#      'CountrySubDivision': ['Derbyshire'],
#      'Country': 'UK',
#      'PostCode': 'NG20 8AL',
#      'GeoLocation': {'GeographicCoordinates': {'Latitude': '53.20298790',
#        'Longitude': '-1.21399030'}}}},
#    {'Identification': '22000054',
#     'SequenceNumber': '0',
#     'Name': 'Barclays bank',
#     'Type': 'Physical',
#     'Photo': 'http://www.barclays.co.uk/branchImages/content/dam/branchfinder/flex-images/CAUK_BankingHub_Logo_Tile for web (002.png',
#     'CustomerSegment': ['Private',
#      'SME',
#      'Premier',
#      'Select',
#      'Wealth',
#      'Corporate',
#      'Business',
#      'Personal'],
#     'Accessibility': ['WheelchairAccess'],
#     'OtherAccessibility': [{'Name': 'Hearing induction loop',
#       'Description': 'Hearing induction loop'}],
#     'Availability': {'StandardAvailability': {'Day': [{'Name': 'Monday',
#         'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#        {'Name': 'Tuesday',
#         'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#        {'Name': 'Wednesday',
#         'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#        {'Name': 'Thursday',
#         'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#        {'Name': 'Friday',
#         'OpeningHours': [{'OpeningTime': '09:00', 'ClosingTime': '17:00'}]},
#        {'Name': 'Saturday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]},
#        {'Name': 'Sunday',
#         'OpeningHours': [{'OpeningTime': '00:00', 'ClosingTime': '00:00'}]}]}},
#     'ContactInfo': [{'ContactContent': '+44-3457345345',
#       'ContactDescription': 'Phone'}],
#     'PostalAddress': {'AddressLine': ['Hometown Hub, Porthouse, 11 Exchange Street'],
#      'BuildingNumber': 'Barclays Bank',
#      'StreetName': 'Banking Hub - Jedburgh',
#      'TownName': 'Jedburgh',
#      'CountrySubDivision': ['Roxburghshire'],
#      'Country': 'UK',
#      'PostCode': 'TD8 6BH',
#      'GeoLocation': {'GeographicCoordinates': {'Latitude': '55.47814200',
#        'Longitude': '-2.55607080'}}}}]}]

# %%
#data['data'][0].keys

# %%
#data['src/main/resources/data'][0].keys()

# %%
f = open(input_file_csv, "w")

f.write('Brand,ID,Type,Branch Name,Town,Postcode,Lat,Long,MonOp,MonCls,TueOp,TueCls,WedOp,WedCls,ThuOp,ThuCls,FriOp,FriCls,SatOp,SatCls,SunOp,SunCls\n')

for brand in data['data'][0]['Brand']:
    for branch in brand['Branch']:
        ID = branch['Identification']
        Btype =  branch ['Type']
        BName = branch['Name']
        town = branch ['PostalAddress'].get('TownName', 'None')
        postcode = branch['PostalAddress']['PostCode']
        try:
            latitude = float(branch ['PostalAddress']['GeoLocation']['GeographicCoordinates']['Latitude'])
            longitude = float(branch['PostalAddress']['GeoLocation']['GeographicCoordinates']['Longitude'])
        except KeyError:
            latitude = 0
            longitude = 0
            
        days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
        opening = {day: {'Open':'00:00', 'Close': '00:00'} for day in days}
        try:
            availability = branch['Availability']['StandardAvailability']['Day']
            for day in availability:
                opening[day['Name']]['Open'] = day['OpeningHours'][0]['OpeningTime']
                opening[day['Name']]['Close'] = day['OpeningHours'][0]['ClosingTime']
        except KeyError:
            pass
        f.write('{0},{1},{2},{3},{4},{5},{6:6f},{7:6f}'.format(brand['BrandName'], ID, Btype, BName, town, postcode, latitude, longitude))
        for day in days:
            f.write(',{0},{1}'.format(opening[day]['Open'],opening[day]['Close']))
        f.write('\n')
f.close()

# %%
# CHECK THE CSV FILE & cORRECTS before reunning this bc it gives many errors

# %%
branches = pd.read_csv(input_file_csv)

# %%
branches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 726 entries, 0 to 725
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Brand        726 non-null    object
#  1   ID           726 non-null    object
#  2   Type         715 non-null    object
#  3   Branch Name  726 non-null    object
#  4   Town         726 non-null    object
#  5   Postcode     726 non-null    object
#  6   Lat          726 non-null    float64
#  7   Long         726 non-null    float64
#  8   MonOp        726 non-null    object
#  9   MonCls       726 non-null    object
#  10  TueOp        726 non-null    object
#  11  TueCls       726 non-null    object
#  12  WedOp        726 non-null    object
#  13  WedCls       726 non-null    object
#  14  ThuOp        726 non-null    object
#  15  ThuCls       726 non-null    object
#  16  FriOp        726 non-null    object
#  17  FriCls       726 non-null    object
#  18  SatOp        726 non-null    object
#  19  SatCls       726 non-null    object
#  20  SunOp        726 non-null    object
#  21  SunCls       726 non-null    object
# dtypes: float64(2), object(20)
# memory usage: 124.9+ KB

# %%
#calculate total open time (in minutes), on a Monday
branches['MonDuration']=(pd.to_datetime(branches['MonCls']) - pd.to_datetime(branches['MonOp']))/np.timedelta64(1,'m')

# %%
#calculate total open time (in minutes), on a Tuesday
branches['TueDuration']=(pd.to_datetime(branches['TueCls']) - pd.to_datetime(branches['TueOp']))/np.timedelta64(1,'m')

# %%
#calculate total open time (in minutes), on a Wednesday
branches['WedDuration']=(pd.to_datetime(branches['WedCls']) - pd.to_datetime(branches['WedOp']))/np.timedelta64(1,'m')

# %%
#calculate total open time (in minutes), on a Thursday
branches['ThuDuration']=(pd.to_datetime(branches['ThuCls']) - pd.to_datetime(branches['ThuOp']))/np.timedelta64(1,'m')

# %%
#calculate total open time (in minutes), on a Friday
branches['FriDuration']=(pd.to_datetime(branches['FriCls']) - pd.to_datetime(branches['FriOp']))/np.timedelta64(1,'m')

# %%
#calculate total open time (in minutes), on a Saturday
branches['SatDuration']=(pd.to_datetime(branches['SatCls']) - pd.to_datetime(branches['SatOp']))/np.timedelta64(1,'m')

# %%
#calculate total open time (in minutes), on a Sunday
branches['SunDuration']=(pd.to_datetime(branches['SunCls']) - pd.to_datetime(branches['SunOp']))/np.timedelta64(1,'m')

# %%
branches['TotalWkOp']= branches['MonDuration']+branches['TueDuration']+ \
                        branches['WedDuration']+branches['ThuDuration']+ \
                        branches['FriDuration']+branches['SatDuration']+branches['SunDuration']

# %%
branches.head()
# Out:
#          Brand             ID      Type    Branch Name             Town  \
# 0  Barclays UK       66000114  Physical  Barclays Bank          Wisbech
# 1  Barclays UK       66000101  Physical  Barclays Bank      Guisborough
# 2  Barclays UK  UK-B-20252909  Physical  Barclays Bank  9-11 Chapel Row
# 3  Barclays UK       66000099  Physical  Barclays Bank          Chorley
# 4  Barclays UK       66000123  Physical  Barclays Bank   Melton Mowbray
#
#    Postcode        Lat      Long  MonOp MonCls  ...  SunOp SunCls MonDuration  \
# 0  PE13 1EU  52.664243  0.161065  00:00  00:00  ...  00:00  00:00         0.0
# 1  TS14 6AP  54.535211 -1.056695  00:00  00:00  ...  00:00  00:00         0.0
# 2  DL12 0SN  54.623238 -2.081710  00:00  00:00  ...  00:00  00:00         0.0
# 3   PR7 1AL  53.654856 -2.629535  09:30  16:30  ...  00:00  00:00       420.0
# 4  LE13 1XD  52.763622 -0.885957  00:00  00:00  ...  00:00  00:00         0.0
#
#   TueDuration WedDuration ThuDuration FriDuration SatDuration SunDuration  \
# 0       420.0         0.0         0.0       420.0         0.0         0.0
# 1       300.0         0.0       300.0         0.0         0.0         0.0
# 2       480.0         0.0         0.0       480.0         0.0         0.0
# 3       420.0         0.0         0.0       420.0         0.0         0.0
# 4       300.0       300.0         0.0       300.0         0.0         0.0
#
#   TotalWkOp
# 0     840.0
# 1     600.0
# 2     960.0
# 3    1260.0
# 4     900.0
#
# [5 rows x 30 columns]

# %%
# The capacity of a branch is defined as the total nr of minutes open per week divided by 2790mins or 46.5h 
# whihc is the typical opening schedule of a physical branch
branches['Capacity']= branches['TotalWkOp']/2790

# %%
branches.to_csv(output_file_csv)

# %%
px.scatter(
    branches, 
    x="Capacity", 
    y="Lat", 
    color='Type',
    title='Barclays Mobile and Physical Branches Capacity by Geographical Latitude, April 2020')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-fb7579455bd1> in <module>
# ----> 1 px.scatter(
#       2     branches,
#       3     x="Capacity",
#       4     y="Lat",
#       5     color='Type',
#
# NameError: name 'px' is not defined

# %%
px.scatter(branches, x="Long", y="Lat", color="Capacity", facet_col="Type",
           color_continuous_scale=px.colors.sequential.Viridis, render_mode="webgl")

# %%
px.set_mapbox_access_token('pk.eyJ1IjoiYW5kcmFzb25lYSIsImEiOiJjam9paTNhaW0wMnU5M3FzMXQwY2FmNmYwIn0.epbBdAlbR55LPW7UF6Gt0w')

# %%
px.scatter_mapbox(branches, lat="Lat", lon="Long", color="Type", size="Capacity", hover_name="Branch Name",
                  color_continuous_scale=px.colors.cyclical.IceFire, size_max=20, zoom=7, title = "Barclays Physical and Mobile Branches, Nov 2019")
